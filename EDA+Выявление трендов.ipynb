# %%
# !pip install pymorphy2
# !pip install -U pymorphy2-dicts-ru
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.1 MB/s
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 20.5 MB/s
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=c16f35862e9e8a2d8c863b15d838b11a7bfde88e47bbe00f6aff04245263e9bc
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymorphy2-dicts-ru in /usr/local/lib/python3.7/dist-packages (2.4.417127.4579844)

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd
import pandas as pd
from collections import Counter
import pymorphy2
import matplotlib.pyplot as plt
import statistics as st
morph = pymorphy2.MorphAnalyzer(lang='ru')

# %%
gdd.download_file_from_google_drive(file_id='10iNZtN0yg0efI3PqWlHrRE1qFVh_n5Gh',
                                    dest_path='./bux_termins')

gdd.download_file_from_google_drive(file_id='1m-cEOV2tMS4WB30je82budBKKtchBmXB',
                                    dest_path='./popular_words')

gdd.download_file_from_google_drive(file_id='1Wa0fCqp4g3YWPwpu1WCw9cBrY6Zu42s8',
                                    dest_path='./economic_words')

gdd.download_file_from_google_drive(file_id='1_5Ud5RaXkguPt0gdZQ7x_QnMOOEy0a3d',
                                    dest_path='./clerk_data')

gdd.download_file_from_google_drive(file_id='1opJBzgtFHnnrNMC9J4cH7V9pa5CZ88fA',
                                    dest_path='./audit_data')

df_clerck = pd.read_csv('clerk_data', sep=';')
df_audit = pd.read_csv('audit_data', sep=';')
# Out:
# Downloading 10iNZtN0yg0efI3PqWlHrRE1qFVh_n5Gh into ./bux_termins... Done.
# Downloading 1m-cEOV2tMS4WB30je82budBKKtchBmXB into ./popular_words... Done.
# Downloading 1Wa0fCqp4g3YWPwpu1WCw9cBrY6Zu42s8 into ./economic_words... Done.
# Downloading 1_5Ud5RaXkguPt0gdZQ7x_QnMOOEy0a3d into ./clerk_data... Done.
# Downloading 1opJBzgtFHnnrNMC9J4cH7V9pa5CZ88fA into ./audit_data... Done.

# %%
def to_norm_form(word):
    return morph.parse(word)[0].normal_form

def to_norm_form_text(text):
    text = text.replace('.', '')
    words = text.split(' ')
    out_text = ''
    for w in words:
        out_text += to_norm_form(w)
        out_text += ' '
    out_text = out_text[:-1]
    return out_text

def to_all_words(line):
    t1 = line['header_news_clear']
    t2 = line['short_description']
    t1 = t1.replace('.', '')
    t2 = t2.replace('.', '')
    t1 = t2.replace(',', '')
    t2 = t2.replace(',', '')
    t1 = t2.replace(':', '')
    t2 = t2.replace(':', '')
    
    t = ''
    for w in t1.split(' '):
        t += w.lower() + ' '
    for w in t2.split(' '):
        t += w.lower() + ' '
    t = t[:-1]
    return t

# %%
bux_termins = []
bux_termins_norm_f = []
with open('bux_termins', 'r') as f:
    for l in f:
        l = l.replace('\n', '')
        bux_termins.append(l)
        bux_termins_norm_f.append(to_norm_form(l))

general_words = []
general_words_norm_f = []
with open('popular_words', 'r') as f:
    for l in f:
        l = l.replace('\n', '')
        general_words.append(l)
        general_words_norm_f.append(to_norm_form(l))

economic_words_norm_f = []
with open('economic_words', 'r') as f:
    for l in f:
        l = l.replace('\n', '')
        economic_words_norm_f.append(to_norm_form(l))

bux_termins_norm_f = list(dict.fromkeys(bux_termins_norm_f))
general_words_norm_f = list(dict.fromkeys(general_words_norm_f))
economic_words_norm_f = list(dict.fromkeys(economic_words_norm_f))

# %%
bux_termins_norm_f
# Out:
# ['аванс',
#  'аккредитив',
#  'аккредитивная форма расчёт',
#  'актив баланс',
#  'активно-пассивные счёт',
#  'активные счёт',
#  'актив',
#  'акцепт',
#  'акцепт счёт',
#  'акцептная форма расчёт',
#  'акциз',
#  'акционер',
#  'акционерное общество',
#  'акционерный капитать',
#  'акция',
#  'акция привилегировать',
#  'акция простый',
#  'амортизируемые актив',
#  'аналитические счёт',
#  'аналитический учёт',
#  'аренда',
#  'арендатор',
#  'арендная плата',
#  'арендодатель',
#  'арифметическая проверка',
#  'аффилированное лицо',
#  'брак в производство',
#  'брак внешний',
#  'брак внутренний',
#  'бухгалтерская отчетность',
#  'бухгалтерский баланс',
#  'бухгалтерский учёт',
#  'валовая продукция',
#  'валюта инострать',
#  'валюта конвертировать',
#  'валюта неконвертировать',
#  'валютное регулирование',
#  'валютный контроль',
#  'валютный курс',
#  'варрант',
#  'векселедатель',
#  'векселедержатель',
#  'вексель',
#  'вексель переводной тратта',
#  'вексель простый',
#  'внеоборотные актив',
#  'внутренняя отчетность',
#  'вспомогательные материал',
#  'гласность учетной политик',
#  'готовая продукция',
#  'двойная запись',
#  'дебиторская задолженность',
#  'дебитор',
#  'декларация налоговый',
#  'декларация таможенный',
#  'денежные средство',
#  'депозитный сертификат',
#  'дивиденд',
#  'дисконтирование',
#  'добавочный капитать',
#  'документация',
#  'документооборот',
#  'документы первичные, сводный',
#  'долговые финансовые вложение',
#  'долгосрочные актив',
#  'долгосрочные обязательство',
#  'долевые финансовые вложение',
#  'дополнительные счёт',
#  'допущение',
#  'доходы будущих период',
#  'забалансовые счёт',
#  'заесть',
#  'залог',
#  'запасные часть',
#  'затраты внепроизводственный',
#  'затраты на оплату труд',
#  'затраты на производство',
#  'импортёр',
#  'инвентаризация',
#  'инвестиция',
#  'инвестор',
#  'индоссамент',
#  'калькуляционные счёт',
#  'калькуляция',
#  'капитал',
#  'капитальные вложение',
#  'кассовый ордер',
#  'коммерческие расход',
#  'комитент',
#  'консигнант',
#  'консигнатор',
#  'консигнация',
#  'коносамент',
#  'контрарные счёт',
#  'косвенные затрат',
#  'корректурный способ',
#  '«красное сторно»',
#  'краткосрочные обязательство',
#  'кредит',
#  'кредит банковский',
#  'кредит коммерческий',
#  'кредитор',
#  'кредиторская задолженность',
#  'лизинг',
#  'лимит касса',
#  'лифо',
#  'наличные расчёт',
#  'налогообложение льготный',
#  'незавершенное производство',
#  'нематериальные актив',
#  'непокрытый убыток',
#  'нераспределенная прибыль',
#  'норма естественной убыль',
#  'ноухау',
#  'облигация',
#  'оборот по счёт',
#  'оборотные актив',
#  'обратные записи проводка',
#  'обязательство',
#  'операционные счёт',
#  'оправдательный документ',
#  'основные материал',
#  'основные средство',
#  'основные счёт',
#  'отчетная дат',
#  'оценка',
#  'пассив баланс',
#  'пассивные счёт',
#  'первичный документ',
#  'первоначальная стоимость',
#  'переоценка основных средство',
#  'платежное поручение',
#  'платежное требование',
#  'подотчетные лица',
#  'полуфабрикат',
#  'поставщик',
#  'пошлина',
#  'предметы обращение',
#  'предметы труд',
#  'прибыль',
#  'привлеченный капитать',
#  'простая форм',
#  'прямые затрат',
#  'разницы инвентаризационный',
#  'распорядительный документ',
#  'расходы будущих период',
#  'расчетно-платежная ведомость',
#  'расчетный счёт',
#  'регистры учетный',
#  'регулирующие счёт',
#  'ремитент',
#  'резерв на оплату отпуск',
#  'резервный капитать',
#  'резервы предстоящих расход',
#  'реквизит',
#  'сальдировать',
#  'сальдо',
#  'себестоимость полный',
#  'себестоимость продукция',
#  'себестоимость цеховой',
#  'сертификат',
#  'синтетические счёт',
#  'система счёт',
#  'систематическая запись',
#  'собственный капитать',
#  'соло-вексель',
#  'средняя себестоимость',
#  'средства в расчёт',
#  'средства производство',
#  'ссуда',
#  'стандарт норма',
#  'структура документ',
#  'субаренда',
#  'субсчёт',
#  'сырьё',
#  'таксировка',
#  'тара',
#  'текущие актив',
#  'твердая цен',
#  'товарная продукция',
#  'товар',
#  'топливо',
#  'трассант',
#  'трассат',
#  'требование',
#  'убыток',
#  'управленческий учёт',
#  'уставный капитать',
#  'учетная политик',
#  'учетная процедур',
#  'учетный цикл',
#  'финансово-результатные счёт',
#  'финансовые вложение',
#  'финансовый учёт',
#  'фифо',
#  'хозяйственная операция',
#  'хозяйствующий субъект',
#  'хронологическая запись',
#  'целевое финансирование',
#  'эмиссия',
#  'эмитент',
#  'юридическое лицо',
#  'бланки строгой отчетность',
#  'бсо',
#  'финансовая отчетность',
#  'бухгалтерская справка',
#  'справка-расчёт',
#  'загранкомандировка',
#  'заграничная командировка',
#  'кассовый аппарат',
#  'ккм, ккт',
#  'корректировочная проводка',
#  'сторно',
#  'лимит остатка наличных денег в касса',
#  'материально-производственные запас',
#  'мпз',
#  'оквэда',
#  'оквэд2',
#  'окпд',
#  'окпд2',
#  'положения по бухгалтерскому учёт',
#  'пбу',
#  'рбп',
#  'росстат',
#  'федеральная служба государственной статистика',
#  'рсб',
#  'российские стандарты бухгалтерского учёт',
#  'синтетический учёт',
#  'синтетический счёт',
#  'товарно-транспортная накладный',
#  'ттн, форма 1-так',
#  'транспортно-заготовительные расход',
#  'тзр',
#  'условное обязательство',
#  'условный актив',
#  'фсб',
#  'енвда',
#  'единый сельскохозяйственный налог',
#  'есхн',
#  'идентификационный номер налогоплательщик',
#  'инна',
#  'индивидуальный предприниматель',
#  'ип',
#  'книга учета доходов и расход',
#  'кудир',
#  'код бюджетной классификация',
#  'кбк',
#  'код причины постановки на учёт',
#  'кпп',
#  'кодекс об административных правонарушение',
#  'коап',
#  'консолидированная группа налогоплательщик',
#  'кгн',
#  'контролируемая иностранная компания',
#  'кик',
#  'легализация доход',
#  'отмывание доходов, полученных преступным путь',
#  'налог на добавленную стоимость',
#  'ндс',
#  'налог на профессиональный доход',
#  'нпд',
#  'налоговый кодекс',
#  'нк рф',
#  'ндфл',
#  'налог на доходы физических лица',
#  'обналичивание денежных средство',
#  'обнал, обналичка',
#  'онлайн-касса',
#  'онлайн-ккт',
#  'оператор фискальных дать',
#  'офд',
#  'осн',
#  'общая система налогообложение',
#  'особая экономическая зон',
#  'оэз',
#  'патентная система налогообложение',
#  'псн',
#  'таможенный кодекс',
#  'тк рф',
#  'универсальный передаточный документ',
#  'упд',
#  'упрощенная система налогообложение',
#  'усн',
#  'аналитические процедура',
#  'мса 520',
#  'мса 540',
#  'аудиторская выборка',
#  'мса 530',
#  'аудиторская документация',
#  'мса 230',
#  'аудиторские доказательство',
#  'мса 500',
#  'мса 510',
#  'аудиторские процедуры в ответ на оцененные риска',
#  'мса 330',
#  'внешние подтверждение',
#  'мса 505',
#  'мса 315 (пересмотренный',
#  'дью дилидженс',
#  'due diligence',
#  'мссу 4400',
#  'задания по компиляция',
#  'мссу 4410',
#  'мсоп 2400',
#  'мса 810',
#  'мсзоу 3420',
#  'мсзоу 3410',
#  'мсзоу 3402',
#  'мса 260 (пересмотренный',
#  'мса 265',
#  'мса 701',
#  'использование работы внутренних аудитор',
#  'мса 610',
#  'использование работы эксперта аудитор',
#  'мса 620',
#  'мса 220',
#  'мсзоу 3000',
#  'модифицированное мнение в аудиторском заключение',
#  'мса 705 (пересмотренный',
#  'непрерывность деятельность',
#  'мса 570',
#  'мсоп 2410',
#  'мса 240',
#  'мса 720 (пересмотренный',
#  'мса 200',
#  'мса 402',
#  'мса 805',
#  'особенности аудита финансовой отчетности группа',
#  'мса 600',
#  'мса 800',
#  'особенности аудита финансовых инструмент',
#  'мопа 1000',
#  'мса 501',
#  'оценка искажений, выявленных в ходе аудит',
#  'мса 450',
#  'письменные заявление',
#  'мса 580',
#  'планирование аудита финансовой отчетность',
#  'мса 300',
#  'проверка прогнозной финансовой информация',
#  'мсзоу 3400',
#  'мса 706 (пересмотренный',
#  'мса 250',
#  'саморегулируемая организация',
#  'сро',
#  'связанные сторона',
#  'мса 550',
#  'события после отчетной дат',
#  'мса 560',
#  'согласование условий аудиторских задание',
#  'мса 210',
#  'мса 710',
#  'мса 320',
#  'мса 700',
#  'административно-управленческий персонал',
#  'ауп',
#  'гражданско-правовой договор',
#  'гпх',
#  'декретный отпуск',
#  'отпуск по беременности и род',
#  'дисциплинарная ответственность',
#  'дисциплинарного взыскание',
#  'кадровик',
#  'hr-менеджер',
#  'ключевой показатель эффективность',
#  'kpi',
#  'минимальная заработная плата',
#  'мрот',
#  'самозанятой',
#  'самозанятые гражданин',
#  'специальная оценка условий труд',
#  'соут',
#  'средний заработка',
#  'средняя заработная плата',
#  'фонд социального страхование',
#  'фсс',
#  'внешнеэкономическая деятельность',
#  'вэд',
#  'государственное унитарное предприятие',
#  'гуп',
#  'гражданский кодекс',
#  'гк рф',
#  'конкурсный управлять',
#  'внешний управлять',
#  'концессия',
#  'договор коммерческой концессия',
#  'муниципальное унитарное предприятие',
#  'муп',
#  'огрн',
#  'основной государственный регистрационный номер',
#  'огрнип',
#  'районный суд',
#  'городской суд',
#  'система быстрых платёж',
#  'сбп',
#  'форвард',
#  'форвардный контракт',
#  'фьючерс',
#  'фьючерсный контракт',
#  'эдо',
#  'электронный документооборот',
#  'электронно-цифровая подпись',
#  'эцп',
#  'аудит',
#  'бухгалтерская запись',
#  'проводка',
#  'бюджет',
#  'бюджетно-распределительные счёт',
#  'валовой внутренний продукт',
#  'валовый городской продукт',
#  'валюта',
#  'вексель переводный',
#  'тратта',
#  'восстановительная стоимость основных средство',
#  'двойное налогообложение',
#  'денежные документ',
#  'денежный эквивалент',
#  'депозит',
#  'документ',
#  'первичные, сводный',
#  'долгосрочные финансовые вложение',
#  'дополнительная запись',
#  'доход по стоимости объекта строительство',
#  'доход по стоимости работ по мере их готовность',
#  'единый налог на вмененный доход',
#  'заёмщик',
#  'импорт',
#  'камеральная проверка',
#  'карточка подпись',
#  'кассовый метод',
#  'комиссионный сбор',
#  'конвертация',
#  'контрагент',
#  'котировка',
#  'краткосрочные финансовые вложение',
#  'кредитный портфель',
#  'ликвидационная стоимость основных средство',
#  'ликвидационный баланс',
#  'материальные актив',
#  'метод начисление',
#  'методический аспект учетной политик',
#  'налог',
#  'налоговая база',
#  'налоговая отчетность',
#  'налоговое планирование',
#  'налоговый учёт',
#  'налогообложение',
#  'налогоплательщик',
#  'нерезидент',
#  'нетто',
#  'номинальная стоимость',
#  'нулевая декларация',
#  'нулевая отчетность',
#  'нулевой баланс',
#  'оборотная ведомость по аналитическим счёт',
#  'оборотная ведомость по синтетическим счёт',
#  'обратные запись',
#  'проводок',
#  'общий',
#  'основная, традиционная, классический',
#  'остаточная стоимость нематериальных актив',
#  'остаточная стоимость основных средство',
#  'отклонение в стоимости материальных ценность',
#  'отчетный период',
#  'персонифицированный учёт',
#  'план счетов бухгалтерского учёт',
#  'положение',
#  'стандарт',
#  'пользователи бухгалтерской информация',
#  'принципы бухгалтерского учёт',
#  'проверка документов по существо',
#  'проводка бухгалтерский',
#  'запись',
#  'простая бухгалтерская проводка',
#  'раздел бухгалтерского баланс',
#  'разделительный баланс',
#  'регистры систематического учёт',
#  'регистры хронологические учёт',
#  'резервный фонд',
#  'резидент',
#  'резидентство',
#  'роялти',
#  'рыночная стоимость',
#  'самозанятый гражданин',
#  'себестоимость производственный',
#  'сертификат налогового резидентство',
#  'система налогообложение',
#  'норма',
#  'статья бухгалтерского баланс',
#  'страховые взнос',
#  'таможенная пошлина',
#  'товарный знак',
#  'товарная марка',
#  'торговый сбор',
#  'упрощённая система налогообложение',
#  'усно «доходы минус расходы»',
#  'усно «доходы»',
#  'факсимиле',
#  'финансовый года',
#  'цб россия',
#  'чистые актив',
#  'шахматная оборотная ведомость',
#  'электронная отчётность',
#  'электронная цифровая подпись',
#  'электронные торг',
#  'дисконт',
#  'брутто']

# %%
df_audit = df_audit.rename(columns={'header': 'header_news_clear', 'description': 'short_description'})

# %%
df_clerck['all_words'] = df_clerck.apply(to_all_words, axis=1)
df_audit['all_words'] = df_audit.apply(to_all_words, axis=1)

df_clerck['all_words_norm_f'] = df_clerck['all_words'].apply(to_norm_form_text)
df_audit['all_words_norm_f'] = df_audit['all_words'].apply(to_norm_form_text)

# %%
df_clerck
# Out:
#      number_news                                   link                 time  \
# 0         535740  https://www.klerk.ru/buh/news/535740/  2022-10-04 06:52:00
# 1         535625  https://www.klerk.ru/buh/news/535625/  2022-09-21 09:50:00
# 2         536305  https://www.klerk.ru/buh/news/536305/  2022-09-28 17:19:00
# 3         534800  https://www.klerk.ru/buh/news/534800/  2022-09-09 11:39:00
# 4         536399  https://www.klerk.ru/buh/news/536399/  2022-09-29 13:16:00
# ..           ...                                    ...                  ...
# 926       537110  https://www.klerk.ru/buh/news/537110/  2022-10-07 16:45:00
# 927       537127  https://www.klerk.ru/buh/news/537127/  2022-10-07 15:13:00
# 928       534994  https://www.klerk.ru/buh/news/534994/  2022-09-12 14:42:00
# 929       537155  https://www.klerk.ru/buh/news/537155/  2022-10-08 08:48:00
# 930       537157  https://www.klerk.ru/buh/news/537157/  2022-10-08 09:15:00
#
#                      rubrication  comments   view  \
# 0                    Мобилизация       881  57170
# 1                    Мобилизация       616  27149
# 2                    Мобилизация        18  60922
# 3                   Санкции 2022       266   7429
# 4                       Политика       210   7499
# ..                           ...       ...    ...
# 926                    Маркетинг         0    353
# 927                    Перевозка         0    324
# 928                Ценные бумаги         0    223
# 929  Электронные трудовые книжки         0     83
# 930                  Мобилизация         0     40
#
#                                      header_news_clear  \
# 0              Что известно о мобилизации на 4 октября
# 1     300 тыс. человек. Объявили, кого будут призыв...
# 2    Объясняем.рф: предельный возраст мобилизации р...
# 3    На Западе заговорили о постепенном снятии санкций
# 4     Завтра Путин выступит в Кремле и подпишет дог...
# ..                                                 ...
# 926  Сеть магазинов OBI готовится к ребрендингу. Сд...
# 927  Спецразрешение для крупногабаритного транспорт...
# 928  Мосбиржа показала положительную динамику после...
# 929  Если работодатель не внес в трудовую книжку за...
# 930  Бухгалтеры думают, как с минимальными налоговы...
#
#                                      short_description  \
# 0    Все новости и комментарии на тему частичной мо...
# 1       Студентов и срочников мобилизация не коснется.
# 2    Предельный возраст призыва рядовых и сержантск...
# 3    Глава МИД Австрии допустил постепенное снятие ...
# 4    Церемония подписания договоров о вступлении в ...
# ..                                                 ...
# 926  Российским магазинам немецкой сети OBI нужно п...
# 927  Электронные разрешения будут оформлять быстрее...
# 928  В начале торгов 12 сентября все фондовые индек...
# 929  Не все кадровики разобрались с электронными тр...
# 930  В Красном уголке бухгалтера живо обсуждают вар...
#
#                                              all_words  \
# 0    все новости и комментарии на тему частичной мо...
# 1    студентов и срочников мобилизация не коснется ...
# 2    предельный возраст призыва рядовых и сержантск...
# 3    глава мид австрии допустил постепенное снятие ...
# 4    церемония подписания договоров о вступлении в ...
# ..                                                 ...
# 926  российским магазинам немецкой сети obi нужно п...
# 927  электронные разрешения будут оформлять быстрее...
# 928  в начале торгов 12 сентября все фондовые индек...
# 929  не все кадровики разобрались с электронными тр...
# 930  в красном уголке бухгалтера живо обсуждают вар...
#
#                                       all_words_norm_f
# 0    всё новость и комментарий на тема частичный мо...
# 1    студент и срочник мобилизация не коснуться сту...
# 2    предельный возраст призыв рядовой и сержантски...
# 3    глава мид австрия допустить постепенный снятие...
# 4    церемония подписание договор о вступление в со...
# ..                                                 ...
# 926  российский магазин немецкий сеть obi нужно про...
# 927  электронный разрешение быть оформлять быстрый ...
# 928  в начало торг 12 сентябрь всё фондовый индекс ...
# 929  не всё кадровик разобраться с электронный труд...
# 930  в красный уголок бухгалтер живо обсуждать вари...
#
# [931 rows x 10 columns]

# %%
df_audit
# Out:
#            time  view                                  header_news_clear  \
# 0    01.09.2022   563  Несвоевременное расторжение срочного трудового...
# 1    01.09.2022   447  Разработаны особые коды для указания в платежк...
# 2    01.09.2022  1227  Новак: Россия не будет поставлять нефть страна...
# 3    01.09.2022   594  В России с 1 сентября заработает система элект...
# 4    01.09.2022   497  Минцифры предложило разрешить отзывать согласи...
# ..          ...   ...                                                ...
# 590  07.10.2022   488  ЕС разрешил разморозить активы российских инве...
# 591  07.10.2022   162  Компания Direcum приглашает на бесплатный веби...
# 592  07.10.2022   823  Аналитик спрогнозировал рост курса доллара до ...
# 593  07.10.2022   220  Сегодня состоится "круглый стол", посвященный ...
# 594  07.10.2022   253  Установлены допусимые доли иностранных работни...
#
#                                      short_description  \
# 0    С работницей был заключен срочный трудовой дог...
# 1    С 1 июля 2022 года действует добровольный спец...
# 2    Идея о лимите цен на нефть РФ является полным ...
# 3    Государственная информационная система электро...
# 4    Министерство цифрового развития, связи и массо...
# ..                                                 ...
# 590  ЕК подтвердила возможность разморозки активов ...
# 591  Работники бегают с бумажными заявлениями по ка...
# 592  Доллар может укрепиться до 65 рублей в течение...
# 593  Сегодня (7 октября) в 15.00 Мск состоится "кру...
# 594  Вводится множество новых исключений для ряда р...
#
#                                              all_words  \
# 0    с работницей был заключен срочный трудовой дог...
# 1    с 1 июля 2022 года действует добровольный спец...
# 2    идея о лимите цен на нефть рф является полным ...
# 3    государственная информационная система электро...
# 4    министерство цифрового развития связи и массов...
# ..                                                 ...
# 590  ек подтвердила возможность разморозки активов ...
# 591  работники бегают с бумажными заявлениями по ка...
# 592  доллар может укрепиться до 65 рублей в течение...
# 593  сегодня (7 октября) в 1500 мск состоится "круг...
# 594  вводится множество новых исключений для ряда р...
#
#                                       all_words_norm_f
# 0    с работница быть заключить срочный трудовой до...
# 1    с 1 июль 2022 год действовать добровольный спе...
# 2    идея о лимит цена на нефть рф являться полный ...
# 3    государственный информационный система электро...
# 4    министерство цифровой развитие связь и массовы...
# ..                                                 ...
# 590  ек подтвердить возможность разморозка актив ро...
# 591  работник бегать с бумажный заявление по кабине...
# 592  доллар мочь укрепиться до 65 рубль в течение п...
# 593  сегодня (7 октября) в 1500 мск состояться "кру...
# 594  вводиться множество новый исключение для ряд р...
#
# [595 rows x 6 columns]

# %%
df_clerck['time'] = pd.to_datetime(df_clerck['time']).dt.date

# %%
df_clerck['all_words'][50]
# Out:
# 'новые поправки в уголовный кодекс ужесточают наказание за срыв гособоронзаказа за неявку или самовольное оставление места военной службы а также за дезертирство и добровольную сдачу в плен новые поправки в уголовный кодекс ужесточают наказание за срыв гособоронзаказа за неявку или самовольное оставление места военной службы а также за дезертирство и добровольную сдачу в плен'

# %% [markdown]
# # Выявление трендовых слов.

# %%
trend_words = {}
trend_words_bux = {}
trend_words_econ = {}

def count_words(text):
    """
    Применив эту функцию к столбцу с описанием или заголовком добавляем слова в словарь трендов.
    """
    global trend_words_norm_f, use_bux_termins_norm_f, bux_termins
    text = text.replace('.', '')
    words = text.split(' ')
    not_general_words = []
    not_general_words_bux = []
    not_general_words_econ = []
    for word in words:
        if word not in general_words_norm_f:
            if word in bux_termins_norm_f:
                not_general_words_bux.append(word.lower())
            if word in economic_words_norm_f:
                not_general_words_econ.append(word.lower())
            not_general_words.append(word.lower())

    count = Counter(not_general_words)
    for word in count.keys():
        if len(word) > 1:
            if word not in trend_words.keys():
                trend_words[word] = count[word]
            else:
                trend_words[word] += count[word]

    count_bux = Counter(not_general_words_bux)
    for word in count_bux.keys():
        if len(word) > 1:
            if word not in trend_words_bux.keys():
                trend_words_bux[word] = count_bux[word]
            else:
                trend_words_bux[word] += count_bux[word]

    count_econ = Counter(not_general_words_econ)
    for word in count_econ.keys():
        if len(word) > 1:
            if word not in trend_words_econ.keys():
                trend_words_econ[word] = count_econ[word]
            else:
                trend_words_econ[word] += count_econ[word]

use_bux_termins = False
df_clerck['all_words_norm_f'].apply(count_words)
df_audit['all_words_norm_f'].apply(count_words)
trend_words = dict(sorted(trend_words.items(), key=lambda item: item[1], reverse=True))

# %%
trend_out = {}
trend_out_econ = {}
trend_out_bux = {}

for k in trend_words.keys():
    trend_out[k] = [trend_words[k], []]

for k in trend_words_econ.keys():
    trend_out_econ[k] = [trend_words_econ[k], []]

for k in trend_words_bux.keys():
    trend_out_bux[k] = [trend_words_bux[k], []]


def count_vews(row):
    view = row['view']
    text = row['all_words_norm_f']
    text = text.split(' ')

    for k in trend_out.keys():
        if k in text:
            trend_out[k][1].append(view)

    for k in trend_out_econ.keys():
        if k in text:
            trend_out_econ[k][1].append(view)
    
    for k in trend_out_bux.keys():
        if k in text:
            trend_out_bux[k][1].append(view)
    
df_clerck.apply(count_vews, axis=1)
df_audit.apply(count_vews, axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 590    None
# 591    None
# 592    None
# 593    None
# 594    None
# Length: 595, dtype: object

# %%
# math
for k in trend_out:
    mean = st.mean(trend_out[k][1])
    if mean > 2500:
        mean = 2500
    trend_out[k][1] = mean
for k in trend_out_econ:
    trend_out_econ[k][1] = st.mean(trend_out_econ[k][1])
for k in trend_out_bux:
    trend_out_bux[k][1] = st.mean(trend_out_bux[k][1])

# %%
x = []
for k in trend_out:
    x.append(trend_out[k][1])
plt.plot(x)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa680688fd0>,
#   <matplotlib.lines.Line2D at 0x7fa67fffc290>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa67fffc7d0>,
#   <matplotlib.lines.Line2D at 0x7fa67fffcd10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa67fff8790>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa6800022d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa680002810>],
#  'means': []}

# %%
x = []
for k in trend_out_econ:
    x.append(trend_out_econ[k][1])
plt.plot(x)

# %%
x = []
for k in trend_out_bux:
    x.append(trend_out_bux[k][1])
plt.plot(x)

# %%
trend_out_econ
# Out:
# {'мобилизация': [188, 4055.7956989247314],
#  'сво': [10, 4880.2],
#  'минфин': [122, 972.1833333333333],
#  'цб': [118, 1228.0535714285713],
#  'ндфл': [74, 1252.969696969697],
#  'рассрочка': [2, 2199],
#  'трансфер': [2, 752],
#  'выгодоприобретатель': [4, 1225.5],
#  'стартап': [4, 1039],
#  'нерезидент': [10, 716],
#  'рецессия': [2, 1063],
#  'импортозамещение': [6, 357],
#  'спекуляция': [2, 892],
#  'дисконт': [2, 2975],
#  'инновация': [2, 843]}

# %%
trend_out_bux
# Out:
# {'кбк': [4, 3964],
#  'оквэда': [14, 2174],
#  'ндс': [88, 1012.7941176470588],
#  'контрагент': [6, 1609.3333333333333],
#  'ип': [48, 1700.2631578947369],
#  'фсс': [18, 1920.888888888889],
#  'фсб': [14, 1342],
#  'ндфл': [74, 1252.969696969697],
#  'кадровик': [14, 1196],
#  'самозанятой': [36, 939.3333333333334],
#  'усн': [22, 1710.2],
#  'псн': [12, 1512.6666666666667],
#  'онлайн-касса': [2, 3094],
#  'аванс': [10, 1136],
#  'гпх': [6, 2275],
#  'нпд': [12, 1178.6666666666667],
#  'реквизит': [6, 1598.6666666666667],
#  'дивиденд': [8, 1030.3333333333333],
#  'мрот': [8, 976.25],
#  'упд': [8, 1281.5],
#  'коап': [2, 1849],
#  'депозит': [12, 1763.6666666666667],
#  'росстат': [8, 963],
#  'арендодатель': [2, 1533],
#  'загранкомандировка': [2, 634],
#  'пбу': [4, 807],
#  'инвентаризация': [2, 1301],
#  'акциз': [10, 764.4],
#  'документооборот': [8, 674.5],
#  'сбп': [4, 856],
#  'конвертация': [12, 514],
#  'эдо': [2, 991],
#  'нерезидент': [10, 716],
#  'аудит': [8, 611],
#  'эцп': [2, 924],
#  'импортёр': [4, 407.5],
#  'эмитент': [14, 763],
#  'резидент': [6, 992.3333333333334],
#  'сальдо': [2, 741],
#  'инна': [6, 1086],
#  'дисконт': [2, 2975],
#  'сро': [4, 383]}

# %%
trend_out
# Out:
# {'2023': [196, 1356.0315789473684],
#  'мобилизация': [188, 2500],
#  '2022': [170, 1646.325],
#  'руб': [168, 1234.9642857142858],
#  'мобилизовать': [134, 1788.0615384615385],
#  'госдума': [126, 1091.063492063492],
#  'минфин': [122, 972.1833333333333],
#  'цб': [118, 1228.0535714285713],
#  'из-за': [90, 1470.3488372093022],
#  'ндс': [88, 1012.7941176470588],
#  'ндфл': [74, 1252.969696969697],
#  'отсрочка': [72, 2500],
#  'тыс': [70, 2349.1481481481483],
#  'копа': [66, 717.7692307692307],
#  'фнс': [62, 1409.3548387096773],
#  'налоговик': [62, 1558.4516129032259],
#  'данные': [56, 1275.7037037037037],
#  'млн': [56, 1210.304347826087],
#  'вычет': [56, 1130.4545454545455],
#  '15': [52, 1059.2083333333333],
#  'ип': [48, 1700.2631578947369],
#  'михаил': [42, 976.1904761904761],
#  'премьер-министр': [40, 998.9],
#  '30': [38, 1412.157894736842],
#  'it-компания': [38, 2133.2105263157896],
#  '2021': [38, 1497.1176470588234],
#  'минцифра': [36, 2500],
#  'минтруд': [36, 1038],
#  'мишустин': [36, 1019],
#  'самозанятой': [36, 939.3333333333334],
#  'алексей': [34, 1545.8823529411766],
#  'владимир': [34, 1059.1176470588234],
#  'нк': [32, 1135.8125],
#  'портал': [32, 856.375],
#  'минэкономразвития': [32, 1093.75],
#  'уведомление': [32, 1676.7142857142858],
#  'физлицо': [32, 1322.0714285714287],
#  'путин': [30, 2026.4666666666667],
#  'вебинар': [30, 1427.3333333333333],
#  '«мир»': [30, 1116.7333333333333],
#  '31': [30, 1016.5],
#  'млрд': [30, 1733.2307692307693],
#  'ипотека': [30, 1073.9333333333334],
#  'сергей': [30, 1196.0714285714287],
#  'малое': [28, 2121.6428571428573],
#  'облагаться': [28, 1154.0833333333333],
#  'пеня': [28, 798.8333333333334],
#  '«известиям»': [28, 1712.5],
#  'среднее': [26, 2063.6153846153848],
#  'госуслуга': [26, 1448.923076923077],
#  '10': [26, 1028.9166666666667],
#  'мошенник': [26, 1647.5384615384614],
#  'мораторий': [26, 863.8461538461538],
#  'днр': [24, 1537],
#  'тк': [24, 2500],
#  'приостановка': [24, 2224.3333333333335],
#  'максим': [24, 1378.75],
#  'александр': [24, 1846.9166666666667],
#  '17': [24, 1392.5833333333333],
#  '12': [24, 1331.3636363636363],
#  'военкомат': [24, 1846.3636363636363],
#  'платёжный': [24, 903.7272727272727],
#  '10%': [24, 833.1666666666666],
#  'лнр': [22, 1601.7272727272727],
#  'аккредитация': [22, 2052.8888888888887],
#  'казахстан': [22, 1176.4],
#  'усн': [22, 1710.2],
#  'лимит': [22, 1310.3],
#  '16': [22, 865.1818181818181],
#  'трлн': [22, 746.6666666666666],
#  '0%': [22, 755.6],
#  'риа': [22, 1196.2727272727273],
#  'вс': [22, 1375.6363636363637],
#  'аккредитовать': [20, 2334.5555555555557],
#  'пфр': [20, 2286.5],
#  'профильный': [20, 1986.625],
#  'бухучёт': [20, 1649.6666666666667],
#  'маркетплейс': [20, 1313.888888888889],
#  '20%': [20, 905],
#  'иа': [20, 979.7],
#  'херсонский': [18, 1999.2222222222222],
#  'запорожский': [18, 1999.2222222222222],
#  'фсс': [18, 1920.888888888889],
#  'набиуллин': [18, 1287.5555555555557],
#  'ккт': [18, 1356.5714285714287],
#  '13': [18, 1483.111111111111],
#  'роструд': [18, 1043.111111111111],
#  'субсидия': [18, 826.8888888888889],
#  'центробанк': [18, 792.6666666666666],
#  'аудиторский': [18, 863.4285714285714],
#  'недружественный': [18, 651.6666666666666],
#  'рбк': [18, 666.2222222222222],
#  'regnum': [18, 612.7777777777778],
#  '21': [16, 1773.375],
#  '27': [16, 1641.625],
#  '100': [16, 2500],
#  'турция': [16, 828.75],
#  'пресс-служба': [16, 821.125],
#  '22': [16, 2052.1428571428573],
#  'эльвира': [16, 1327.375],
#  '11': [16, 1066.5714285714287],
#  'минпромторг': [16, 954.5],
#  'юань': [16, 1049.375],
#  'чм': [16, 1129.625],
#  'юрлицо': [16, 683],
#  'мосбиржа': [16, 2500],
#  'вице-премьер': [16, 596.375],
#  'повыситься': [16, 776.5],
#  'it': [14, 2500],
#  'контрактник': [14, 2500],
#  '300': [14, 2500],
#  'оквэда': [14, 2174],
#  'бронь': [14, 2086.5],
#  'банкомат': [14, 2500],
#  'минобороны': [14, 2352.8571428571427],
#  'фсб': [14, 1342],
#  'кадровик': [14, 1196],
#  'прожиточный': [14, 1540.3333333333333],
#  'бренд': [14, 1086.2857142857142],
#  'замглавы': [14, 762.4285714285714],
#  '2024': [14, 1069.2857142857142],
#  'роскомнадзор': [14, 1179.2857142857142],
#  'кадастровый': [14, 1439.4],
#  'антон': [14, 753.4285714285714],
#  'белоруссия': [14, 544.2857142857143],
#  'эмитент': [14, 763],
#  'решетник': [14, 472.7142857142857],
#  'кабмин': [14, 1463.142857142857],
#  'андрей': [14, 670],
#  'ефс-1': [12, 2500],
#  'сзв-тд': [12, 2500],
#  'приостанавливаться': [12, 2277.8333333333335],
#  'критически': [12, 1423.6666666666667],
#  'соответствующий': [12, 832.8333333333334],
#  'рассылка': [12, 2269.1666666666665],
#  '2025': [12, 1187.5],
#  'проиндексировать': [12, 1025.8333333333333],
#  'ифнс': [12, 1306],
#  'ozon': [12, 1377],
#  'wildberries': [12, 1790.1666666666667],
#  'псн': [12, 1512.6666666666667],
#  'нпд': [12, 1178.6666666666667],
#  'ужесточить': [12, 1274.1666666666667],
#  'приостановление': [12, 816.6666666666666],
#  'крым': [12, 932.8],
#  'сверка': [12, 1101.6666666666667],
#  'по-прежнему': [12, 1447.8333333333333],
#  '400': [12, 799.3333333333334],
#  'депозит': [12, 1763.6666666666667],
#  '28': [12, 664.3333333333334],
#  'сбербанк': [12, 673.3333333333334],
#  'минсельхоз': [12, 706.3333333333334],
#  'облагать': [12, 710.8333333333334],
#  'конвертация': [12, 514],
#  'скорее': [12, 869],
#  'мсп': [12, 845.5],
#  'сазан': [12, 1464.3333333333333],
#  'брокер': [12, 542.1666666666666],
#  'аусна': [12, 582.8],
#  'еаэс': [12, 708],
#  '23': [12, 2148.6666666666665],
#  'зампред': [12, 769],
#  'пф': [12, 1285],
#  '60': [10, 2500],
#  'сво': [10, 2500],
#  'увольнять': [10, 2500],
#  'тд': [10, 2500],
#  'бухгалтерия': [10, 1362.4],
#  '30%': [10, 2215],
#  'возобновление': [10, 1566.4],
#  'заблокировать': [10, 1391.8],
#  'главбух': [10, 1738.6],
#  'кто-то': [10, 1277.6666666666667],
#  'володин': [10, 1201.4],
#  'санкционный': [10, 770.4],
#  '75%': [10, 1625],
#  '6%': [10, 1600.4],
#  'нетрудоспособность': [10, 903],
#  'аванс': [10, 1136],
#  'избежание': [10, 1025],
#  'минтранс': [10, 825.5],
#  'ооо': [10, 1024.25],
#  'ст': [10, 800.2],
#  'злоумышленник': [10, 939.6],
#  'арендный': [10, 673.5],
#  'акциз': [10, 764.4],
#  'застройщик': [10, 621.6],
#  '14': [10, 888.6],
#  'нерезидент': [10, 716],
#  'основное': [10, 558.2],
#  'малоимущий': [10, 1864.25],
#  'ндпить': [10, 488],
#  '20': [10, 785],
#  'моисеев': [10, 649.6],
#  'намерить': [10, 574.2],
#  'игорь': [10, 1000.6],
#  'дмитрий': [10, 2406],
#  'евросоюз': [10, 411.6],
#  'пресс-секретарь': [8, 2500],
#  'подлежащее': [8, 2235.5],
#  '50%': [8, 2120.25],
#  'анонсировать': [8, 2500],
#  'призывный': [8, 1617],
#  'вячеслав': [8, 1868.5],
#  '26': [8, 1728.25],
#  '1с': [8, 2134.5],
#  'приостанавливать': [8, 2011.5],
#  'маркировка': [8, 1526],
#  'санкт-петербург': [8, 1982.5],
#  'фас': [8, 1147.75],
#  'беременная': [8, 2486.5],
#  'корректировка': [8, 1551.75],
#  '15%': [8, 2056],
#  'гибдд': [8, 1439.25],
#  '55': [8, 1803.5],
#  'беларусь': [8, 1672.5],
#  'осаго': [8, 1333.5],
#  'автовладелец': [8, 1497.25],
#  'банкрот': [8, 1289.5],
#  '200': [8, 925.75],
#  'плательщик': [8, 1498.75],
#  'латвия': [8, 1228.25],
#  'счёт-фактура': [8, 1362],
#  'дивиденд': [8, 1030.3333333333333],
#  'вакансия': [8, 1197.25],
#  'мошеннический': [8, 1003],
#  'учётный': [8, 1481.75],
#  '1%': [8, 1146.25],
#  'массово': [8, 800],
#  '25': [8, 1196.75],
#  'ос': [8, 1452.75],
#  'начисление': [8, 1349.25],
#  'мрот': [8, 976.25],
#  '2019': [8, 906],
#  'отчитываться': [8, 1103.75],
#  'фтс': [8, 1134],
#  'упд': [8, 1281.5],
#  'минприрода': [8, 760.5],
#  'россии»': [8, 1120],
#  'софт': [8, 977.5],
#  'индексация': [8, 836.75],
#  'росстат': [8, 963],
#  'евгений': [8, 1700.75],
#  'сбер': [8, 965.5],
#  'онлайн': [8, 766.5],
#  'армения': [8, 871.25],
#  'документооборот': [8, 674.5],
#  '70': [8, 1315],
#  'бухотчётность': [8, 852.75],
#  'жкх': [8, 535.75],
#  'беспошлинный': [8, 833.25],
#  'ввоз': [8, 2295.75],
#  'аудит': [8, 611],
#  'наслать': [8, 816.25],
#  'социально-экономический': [8, 729.75],
#  'полис': [8, 896.25],
#  'рекордный': [8, 954.75],
#  'неквалифицированный': [8, 483],
#  'мвд': [8, 573.6666666666666],
#  'микрозаём': [8, 434.75],
#  '2023-2025': [8, 552],
#  'списывать': [8, 1004],
#  'антимонопольный': [8, 811.6666666666666],
#  'telegram-канал': [8, 903.25],
#  'ук': [8, 1474],
#  '«альфа-капитал»': [8, 1474],
#  'тасс': [8, 1958.5],
#  '«известий»': [8, 709.25],
#  '&gt;&gt;&gt;': [8, 1891.25],
#  'лдпр': [8, 906.75],
#  'высокооплачиваемый': [8, 718.6666666666666],
#  'иван': [8, 753.25],
#  '"коммерсант"': [8, 373.75],
#  '50': [6, 2500],
#  '65': [6, 2500],
#  '195': [6, 2500],
#  'призывник': [6, 2500],
#  'начислить': [6, 2500],
#  'грамотность': [6, 1449.3333333333333],
#  '3517': [6, 1912.3333333333333],
#  'стимулирование': [6, 1812.6666666666667],
#  '182н': [6, 2500],
#  'белгородский': [6, 1788],
#  '(работа': [6, 1607.6666666666667],
#  'контрагент': [6, 1609.3333333333333],
#  'годность': [6, 2067.3333333333335],
#  'анатолий': [6, 1669],
#  'аксаков': [6, 1669],
#  'начислять': [6, 2500],
#  '70%': [6, 1408.3333333333333],
#  '5%': [6, 1673.6666666666667],
#  'потенциально': [6, 2500],
#  '2026': [6, 914],
#  'максут': [6, 2500],
#  'шадаев': [6, 2500],
#  'получатель': [6, 1298.6666666666667],
#  'it-специалист': [6, 1420.6666666666667],
#  '46': [6, 1972.3333333333333],
#  'экипировка': [6, 1409.6666666666667],
#  '2014': [6, 1904.6666666666667],
#  'всё-таки': [6, 1454],
#  'распечатать': [6, 2170],
#  'windows': [6, 813],
#  '2015': [6, 2500],
#  '100%': [6, 1599.3333333333333],
#  'прогул': [6, 1240],
#  '(до': [6, 1916.6666666666667],
#  '24': [6, 1800.3333333333333],
#  'занятой': [6, 1537.6666666666667],
#  'нотариальный': [6, 2500],
#  'гпх': [6, 2275],
#  'размещать': [6, 960],
#  'соцсеть': [6, 1083.6666666666667],
#  'реквизит': [6, 1598.6666666666667],
#  'альфа-банк': [6, 1389.6666666666667],
#  'ольга': [6, 739.6666666666666],
#  'оформляться': [6, 865.3333333333334],
#  'мобилизационный': [6, 1494.3333333333333],
#  'аннулировать': [6, 1744.3333333333333],
#  '000': [6, 1575.6666666666667],
#  'поменяться': [6, 1982.3333333333333],
#  'недобросовестный': [6, 1144.3333333333333],
#  'кассовый': [6, 1792.3333333333333],
#  'взимание': [6, 813.3333333333334],
#  'оспорить': [6, 1493],
#  'травматизм': [6, 1412.3333333333333],
#  'мойка': [6, 710],
#  'грузия': [6, 928.3333333333334],
#  'подорожать': [6, 1187.6666666666667],
#  'программно-аппаратный': [6, 1125],
#  'фискальный': [6, 862.6666666666666],
#  'неработающий': [6, 1063],
#  'безотзывный': [6, 1090.6666666666667],
#  'списание': [6, 892.5],
#  '500': [6, 913.6666666666666],
#  '«единый': [6, 1209.6666666666667],
#  'послабление': [6, 2015],
#  'ес': [6, 1258],
#  '«клерке»': [6, 1174.3333333333333],
#  'toyota': [6, 836.3333333333334],
#  '149': [6, 1002.6666666666666],
#  'выкупить': [6, 884.3333333333334],
#  'apple': [6, 969],
#  'ретейлер': [6, 1003.6666666666666],
#  '2%': [6, 1067],
#  'мсфо': [6, 841],
#  '(ifrs)': [6, 841],
#  'ежемесячный': [6, 610],
#  'узбекистан': [6, 917.3333333333334],
#  '8%': [6, 1240],
#  '2020': [6, 843.3333333333334],
#  'тестировать': [6, 803.3333333333334],
#  'выемка': [6, 971.6666666666666],
#  'дистанционный': [6, 674],
#  'безналичный': [6, 1181.6666666666667],
#  'доначисление': [6, 1123.3333333333333],
#  'разморозка': [6, 772.5],
#  'криптовалюта': [6, 679.6666666666666],
#  'субсидировать': [6, 680.3333333333334],
#  'айтишник': [6, 842.3333333333334],
#  'евразийский': [6, 912],
#  'трата': [6, 1293.6666666666667],
#  '22%': [6, 845],
#  'заём': [6, 696],
#  'системообразующий': [6, 784.3333333333334],
#  'мспрф': [6, 762.3333333333334],
#  'безработный': [6, 1155.6666666666667],
#  'уволиться': [6, 982.6666666666666],
#  'истекать': [6, 646.6666666666666],
#  'прорабатывать': [6, 688],
#  'уведомить': [6, 828],
#  'рейтинговый': [6, 750.6666666666666],
#  'спрогнозировать': [6, 1064.3333333333333],
#  'драгметалл': [6, 519.3333333333334],
#  'ребрендинг': [6, 560.6666666666666],
#  'втб': [6, 557.3333333333334],
#  '17%': [6, 759.6666666666666],
#  '40': [6, 1407.6666666666667],
#  'расписка': [6, 425.3333333333333],
#  'госрегистрация': [6, 455.6666666666667],
#  'авто': [6, 604],
#  '1500': [6, 327.6666666666667],
#  'миронов': [6, 919.3333333333334],
#  'ввп': [6, 517],
#  'страхователь': [6, 362.3333333333333],
#  'sputnik': [6, 766.6666666666666],
#  'резидент': [6, 992.3333333333334],
#  'промышленник': [6, 948.3333333333334],
#  'пленарный': [6, 1180.6666666666667],
#  'минэкономики': [6, 368],
#  '«вечерня': [6, 2500],
#  'исчислить': [6, 504],
#  'б/с': [6, 323],
#  'superjob': [6, 2002],
#  'rt': [6, 829.3333333333334],
#  'еврокомиссия': [6, 456],
#  'новостройка': [6, 1715.5],
#  '"каникулы"': [6, 729.3333333333334],
#  'импортозамещение': [6, 357],
#  'незаконно': [6, 935.3333333333334],
#  'инна': [6, 1086],
#  'белоус': [6, 428],
#  '"о': [6, 1334],
#  'макроэкономический': [6, 1112],
#  'краткосрочный': [6, 1411.6666666666667],
#  'мид': [4, 2500],
#  'обнародовать': [4, 2500],
#  '712': [4, 2500],
#  '«сведение': [4, 2500],
#  'персучёт': [4, 2500],
#  'производстве»': [4, 2500],
#  'вели': [4, 2500],
#  'очный': [4, 2500],
#  'очно-заочный': [4, 2500],
#  'упрощать': [4, 2500],
#  'повторно': [4, 2500],
#  'кбк': [4, 2500],
#  '102': [4, 2427],
#  'ростуризм': [4, 2223],
#  'гособоронзаказ': [4, 2500],
#  'неявка': [4, 2500],
#  'оставление': [4, 2500],
#  'услуг)': [4, 2023.5],
#  'росстандарт': [4, 2500],
#  'фитнес-клуб': [4, 2080.5],
#  '«у': [4, 2212.5],
#  'спецоценка': [4, 2123],
#  'нанимать': [4, 2286],
#  'ратификация': [4, 1146],
#  'медиа': [4, 2500],
#  'туроператор': [4, 1105],
#  'майнинга': [4, 1304],
#  'договорный': [4, 2138.5],
#  'прослеживаемость': [4, 2500],
#  'штрафовать': [4, 2500],
#  'запросить': [4, 1134.5],
#  '$400': [4, 664],
#  'инвестировать': [4, 2004],
#  'нпф': [4, 2500],
#  'иванович': [4, 2500],
#  'ikea': [4, 2500],
#  'осный': [4, 1917.5],
#  'капремонт': [4, 2500],
#  'фссп': [4, 1143],
#  'водительский': [4, 1664],
#  'роды': [4, 1713.5],
#  'пересчитывать': [4, 1928.5],
#  '188': [4, 2203.5],
#  '250': [4, 2406],
#  'снилс': [4, 2261],
#  'приёмка': [4, 2394.5],
#  'шенгенский': [4, 1405.5],
#  'матвиенко': [4, 1959.5],
#  'нецелесообразный': [4, 2129],
#  '1/3': [4, 2091],
#  'даниил': [4, 1215.5],
#  'егоров': [4, 1215.5],
#  'проактивный': [4, 1710.5],
#  '«этый': [4, 1601],
#  'рассылать': [4, 2386],
#  'подраздел': [4, 2318],
#  '41%': [4, 693],
#  'довольствие': [4, 2500],
#  '(переть': [4, 1441],
#  'пристав': [4, 1449.5],
#  'дорогой': [4, 1715.5],
#  'вредить': [4, 1203],
#  'прослеживать': [4, 1808.5],
#  'баталин': [4, 898.5],
#  'озвучить': [4, 844],
#  'топ': [4, 1760.5],
#  'ростов-на-дону': [4, 1668.5],
#  'продлевать': [4, 1202.5],
#  'накопительный': [4, 1490.5],
#  'adidas': [4, 1515.5],
#  'неуплата': [4, 1504],
#  'тимбилдинг': [4, 1623],
#  'тульский': [4, 1323],
#  'возмещать': [4, 1131],
#  '(сфр)': [4, 2458],
#  'ежемесячно': [4, 1561],
#  'штрихкод': [4, 1442],
#  'bank': [4, 1554],
#  'гарантийный': [4, 1644],
#  'ввозить': [4, 922.5],
#  '«на': [4, 916.5],
#  'профзаболевание': [4, 1544.5],
#  'разовый': [4, 1293],
#  '26%': [4, 1235],
#  'поддельный': [4, 2492],
#  'несвоевременный': [4, 2500],
#  'загранпаспорт': [4, 1063],
#  'комплектующие': [4, 824],
#  '(противодействия)': [4, 2353],
#  'ратифицировать': [4, 537.5],
#  'пилотный': [4, 1232],
#  'банкинг': [4, 1298],
#  '864': [4, 1046],
#  'гоз': [4, 1364],
#  'гис': [4, 907],
#  'графа': [4, 1913],
#  '135': [4, 654],
#  'спецоперация': [4, 1180],
#  'легализовать': [4, 935],
#  'въезжать': [4, 1489.5],
#  'трудоустройство': [4, 1077],
#  'кризисный': [4, 1475],
#  'общепит': [4, 1028],
#  '350': [4, 1485],
#  'суточный': [4, 1215.5],
#  'партнёрский': [4, 1383],
#  'активизироваться': [4, 2118],
#  'визовый': [4, 1172.5],
#  'выгодоприобретатель': [4, 1225.5],
#  'санаторно-курортный': [4, 1300],
#  'п9': [4, 995],
#  'собянин': [4, 1357.5],
#  'окз': [4, 1191.5],
#  'черногория': [4, 935],
#  '6/2020': [4, 1114],
#  'автоконцерн': [4, 984],
#  '05': [4, 1371.5],
#  'пп': [4, 966],
#  'it-бизнес': [4, 1110],
#  'стартап': [4, 1039],
#  'пбу': [4, 807],
#  'шойгу': [4, 1564.5],
#  'допуск': [4, 819],
#  'вечером': [4, 1001.5],
#  'мессенджер': [4, 943.5],
#  '25/2018': [4, 1335],
#  'ппа': [4, 1087.5],
#  '«об': [4, 955.5],
#  '76%': [4, 1000],
#  'тратиться': [4, 944.5],
#  'карточный': [4, 2500],
#  'revolut': [4, 1160],
#  'подключиться': [4, 1035],
#  'продление': [4, 758],
#  '(иис)': [4, 721.5],
#  'возгорание': [4, 954.5],
#  'рсв': [4, 2136],
#  'дебетовый': [4, 1034],
#  'кешбэк': [4, 852],
#  'поблажка': [4, 929],
#  'адвокатский': [4, 999.5],
#  'учете»': [4, 1105.5],
#  'совершенствовать': [4, 1163],
#  'сбп': [4, 856],
#  'зачислить': [4, 746],
#  '«кнопка»': [4, 1140],
#  'смартфон': [4, 973.5],
#  'предупредительный': [4, 715],
#  '46%': [4, 765.5],
#  'предзаказ': [4, 933],
#  '990': [4, 933],
#  '60%': [4, 837],
#  'непристегнуть': [4, 1118],
#  'внереализационный': [4, 1033.5],
#  'partners': [4, 814.5],
#  'fix': [4, 820.5],
#  'price': [4, 820.5],
#  '52': [4, 816.5],
#  'росреестр': [4, 553.5],
#  'вредоносный': [4, 739],
#  '859%': [4, 795.5],
#  'выездной': [4, 795.5],
#  'мфц': [4, 765],
#  'силуановый': [4, 773],
#  'провайдер': [4, 605],
#  'онлайн-школа': [4, 895.5],
#  'графика': [4, 1423.5],
#  'гир': [4, 811.5],
#  'бо': [4, 811.5],
#  'товаропроизводитель': [4, 641],
#  '€1000': [4, 807.5],
#  'хозпостройка': [4, 993],
#  '(центробанк': [4, 864],
#  'цб)': [4, 864],
#  '«двигать»': [4, 864],
#  '4%': [4, 569.5],
#  '«клеркпремиум»': [4, 720.5],
#  '29': [4, 1043.5],
#  'финляндия': [4, 758.5],
#  '9%': [4, 670.5],
#  'нк)': [4, 785],
#  'аутсорсинг': [4, 793],
#  '«клерк»': [4, 861.5],
#  '124%': [4, 657.5],
#  'предпенсионер': [4, 752],
#  '2018': [4, 773.5],
#  'appstore': [4, 752.5],
#  'киргизия': [4, 856],
#  'нежилой': [4, 760],
#  'неограниченный': [4, 665.5],
#  '3%': [4, 834],
#  'удалённый': [4, 724.5],
#  'экстренный': [4, 2293.5],
#  'реорганизовать': [4, 663.5],
#  'лизинговый': [4, 509.5],
#  'товарооборот': [4, 735],
#  'приравниваться': [4, 758],
#  'благотворительность': [4, 590.5],
#  '1000': [4, 991],
#  'рецептурный': [4, 553],
#  'топ-15': [4, 731.5],
#  'просрочить': [4, 696.5],
#  'вина': [4, 505.5],
#  'запчасть': [4, 569.5],
#  'ндд': [4, 505],
#  'импортёр': [4, 407.5],
#  'vk': [4, 691],
#  'club': [4, 778],
#  'фз': [4, 589.5],
#  'татарстан': [4, 710.5],
#  'поощрение': [4, 480.5],
#  'капиталовложение': [4, 480.5],
#  'дилерский': [4, 528],
#  'подмосковье': [4, 684.5],
#  'депозитарий': [4, 2500],
#  'наравне': [4, 527.5],
#  'госкомпания': [4, 615],
#  'денис': [4, 538],
#  'мантур': [4, 538],
#  '(от': [4, 535.5],
#  'госзакупка': [4, 597],
#  '65%': [4, 612.5],
#  '56': [4, 1589.5],
#  'mazda': [4, 594.5],
#  'просрочка': [4, 540],
#  'коронавирус': [4, 474.5],
#  'mazars': [4, 664.5],
#  'слиток': [4, 561.5],
#  'проинформировать': [4, 393],
#  'отзывный': [4, 393],
#  'qiwi': [4, 552],
#  '32%': [4, 596.5],
#  '557': [4, 587.5],
#  'восстанавливаться': [4, 599.5],
#  'иис': [4, 593],
#  'unionpay': [4, 507.5],
#  '05%': [4, 510],
#  '24%': [4, 449],
#  'некоммерческий': [4, 481.5],
#  'перераспределить': [4, 396.5],
#  'экспортёр': [4, 809.5],
#  'испытательный': [4, 852],
#  'зарегистрироваться': [4, 770],
#  'москвы»': [4, 1222],
#  'рублёвый': [4, 2500],
#  'депозитарный': [4, 382.5],
#  'замедлиться': [4, 353],
#  '(на': [4, 1119],
#  'ужесточение': [4, 2500],
#  'базисный': [4, 1659.5],
#  'джиоев': [4, 1232.5],
#  'аналитика': [4, 2500],
#  '134': [4, 480.5],
#  '«интерфакс»': [4, 714.5],
#  'срзп': [4, 888],
#  '23%': [4, 567.5],
#  '"согласие"': [4, 2500],
#  'баррель': [4, 1202],
#  'инвестирование': [4, 1582],
#  'мск': [4, 546],
#  '«деловой': [4, 552.5],
#  'коррекция': [4, 2500],
#  'неприменение': [4, 1132],
#  'жилищно-коммунальный': [4, 1171],
#  'скупка': [4, 599],
#  'упростить': [4, 890],
#  '«этажи»': [4, 1997],
#  '(вэф)': [4, 528.5],
#  'ernst': [4, 635],
#  '&amp;': [4, 635],
#  'young': [4, 635],
#  '2030': [4, 302],
#  'предусмотренный': [4, 821],
#  'пропорционально': [4, 1143],
#  'зампредседателя': [4, 2500],
#  'совфеда': [4, 1807],
#  'тренд': [4, 627.5],
#  'краснов': [4, 421.5],
#  'bloomberg': [4, 1205.5],
#  'москвой»': [4, 2500],
#  'перерасчёт': [4, 2500],
#  'пассив': [4, 2248],
#  'взыскать': [4, 427.5],
#  'недоимка': [4, 427.5],
#  'леонид': [4, 460],
#  'горнина': [4, 460],
#  '«работару»': [4, 898.5],
#  'вразрез': [4, 1543],
#  'выманивание': [4, 572],
#  'инфляционный': [4, 839],
#  '"прайм"': [4, 810.5],
#  '19': [4, 617.5],
#  'карантин': [4, 1478],
#  'денежно-кредитный': [4, 1524],
#  'опек': [4, 323],
#  'взаимозачёт': [4, 443],
#  '2023–2025': [4, 742.5],
#  'стойкость': [4, 2500],
#  'чебесков': [4, 371.5],
#  'аудиторов»': [4, 982],
#  'zoom': [4, 648.5],
#  '(мск)': [4, 730],
#  'оговорить': [4, 2492],
#  'трёхлетний': [4, 399],
#  'стратег': [4, 2500],
#  'бахтин': [4, 2500],
#  '19%': [4, 466.5],
#  '“ъ”': [4, 419],
#  '«известия»': [4, 2470],
#  'наталья': [4, 352.5],
#  'дольщик': [4, 385],
#  'антироссийский': [4, 642],
#  'законодательно': [4, 342.5],
#  'новшество': [4, 446.5],
#  'замруководитель': [4, 324],
#  'артём': [4, 895],
#  'потребкредит': [4, 369.5],
#  'фиксация': [4, 2172.5],
#  'ру»': [4, 1776.5],
#  '2016': [4, 461.5],
#  'нина': [4, 508],
#  'останин': [4, 508],
#  'донбасс': [4, 506.5],
#  'владислав': [4, 1071],
#  'суверенный': [4, 564.5],
#  'корректировать': [4, 338],
#  'ускоренный': [4, 1362.5],
#  'нацвалюта': [4, 522],
#  '(цмакп)': [4, 1112],
#  'россии"': [4, 351.5],
#  '22h2': [4, 460.5],
#  'перечисление': [4, 659],
#  'смягчить': [4, 2500],
#  'ек': [4, 437],
#  'заботкин': [4, 2500],
#  'укрепиться': [4, 653.5],
#  '32': [4, 815.5],
#  'клиринговый': [4, 2500],
#  '(нкц)': [4, 2500],
#  'нкц': [4, 2500],
#  'сро': [4, 383],
#  'аас': [4, 383],
#  'валерий': [4, 808],
#  '"госуслуги"': [4, 837],
#  'рубля)': [4, 2500],
#  'головченко': [4, 286.5],
#  'коксоваться': [4, 234.5],
#  '2514': [4, 461],
#  'срочник': [2, 2500],
#  'сержантский': [2, 2500],
#  'австрия': [2, 2500],
#  '2609': [2, 2500],
#  'гигиена': [2, 2500],
#  'соцстрахование': [2, 2500],
#  'надбавка': [2, 2500],
#  'георгиевский': [2, 2500],
#  'высококвалифицированный': [2, 2500],
#  'неправомерно': [2, 2500],
#  '№7': [2, 2500],
#  '10-11': [2, 1705],
#  'обществознание': [2, 1705],
#  'спальная': [2, 2500],
#  'термобельё': [2, 2500],
#  '10-20%': [2, 2500],
#  'платёжка': [2, 2500],
#  'октмый': [2, 2500],
#  '«налоговый': [2, 2500],
#  'тайна»': [2, 2500],
#  'интригующий': [2, 2289],
#  'клерк': [2, 2289],
#  'мерч': [2, 2289],
#  'толстовка': [2, 2289],
#  'принтом': [2, 2289],
#  'стиль!': [2, 2289],
#  'гладков': [2, 2500],
#  'заговаривать': [2, 2500],
#  'ужесточать': [2, 2500],
#  'самовольный': [2, 2500],
#  'дезертирство': [2, 2500],
#  'счетно-сортировальный': [2, 2500],
#  'валидатор': [2, 2500],
#  '115-фз': [2, 2500],
#  'него?': [2, 2500],
#  'отчетностью?': [2, 2500],
#  '«новое': [2, 2500],
#  'люди»': [2, 2500],
#  'решетников': [2, 2500],
#  'скан': [2, 2500],
#  'разбогатеть': [2, 2180],
#  'iт-компания': [2, 2500],
#  'привлекаться': [2, 2500],
#  'брифинг': [2, 2500],
#  'специальности»': [2, 2500],
#  '40-50%': [2, 1661],
#  'медучреждение': [2, 2500],
#  'говорящий': [2, 2500],
#  'квд': [2, 2500],
#  'радикулит': [2, 2500],
#  'сзв-стаж': [2, 2500],
#  'безвизовый': [2, 2500],
#  'сторонний': [2, 2500],
#  'кудрин': [2, 2500],
#  '«яндекс»': [2, 2500],
#  'увозить': [2, 2500],
#  '«кадровый': [2, 2500],
#  'дырами»': [2, 2500],
#  'работник-мужчина': [2, 2500],
#  '«эвакуировали»': [2, 2500],
#  'iт': [2, 2500],
#  '(атор)': [2, 1337],
#  '205': [2, 2500],
#  'якутия': [2, 2500],
#  'авдонин': [2, 2500],
#  'авиабилет': [2, 1920],
#  'хождение': [2, 1989],
#  '44-фз': [2, 2500],
#  '25-го': [2, 2500],
#  '28-быть': [2, 2500],
#  'студент-очник': [2, 2500],
#  'магистратура': [2, 2500],
#  'заочный': [2, 2500],
#  '$100': [2, 1027],
#  '«бумажный': [2, 2500],
#  'привычки»': [2, 2500],
#  'файл': [2, 2500],
#  'невыход': [2, 1910],
#  'образцово': [2, 1470],
#  'раскритиковать': [2, 1858],
#  'иванов': [2, 2500],
#  'анна': [2, 2500],
#  'абрамович': [2, 2500],
#  'изольда': [2, 2500],
#  'призадуматься': [2, 2500],
#  'mcdonald’s': [2, 2094],
#  '3-ндфл': [2, 2500],
#  '13%': [2, 2500],
#  'разворачивать': [2, 2500],
#  'репатриация': [2, 2500],
#  'великобритания': [2, 1398],
#  'microsoft': [2, 1518],
#  'раскусить': [2, 2500],
#  'разыграть': [2, 2500],
#  'микроэлектроника': [2, 1854],
#  'нуждаемость': [2, 2500],
#  'маркетплейс?': [2, 2500],
#  '15%)': [2, 2500],
#  'лесопромышленный': [2, 2500],
#  'переориентация': [2, 2500],
#  'спч': [2, 2500],
#  'точен': [2, 2500],
#  'взыскивать': [2, 2192],
#  'внесудебный': [2, 2192],
#  'летательный': [2, 2500],
#  'дтп': [2, 2500],
#  '6038-у': [2, 2500],
#  'нововведение': [2, 2475],
#  'прибалтийский': [2, 1524],
#  'mango': [2, 2500],
#  'zara': [2, 2500],
#  'коворкинг': [2, 2023],
#  'золотовалютный': [2, 1200],
#  'бережливый': [2, 2084],
#  'финорганизация': [2, 2500],
#  'бизнес-омбудсмен': [2, 1544],
#  '«забизнесрф»': [2, 1544],
#  'элина': [2, 1544],
#  'сидоренко': [2, 1544],
#  '136': [2, 1457],
#  'полмесяца': [2, 1457],
#  '(без': [2, 1072],
#  'заявлений)': [2, 1072],
#  'подмога': [2, 2403],
#  'напрягаться': [2, 2403],
#  'зачем?': [2, 2403],
#  'хотите?»': [2, 2403],
#  'неполученный': [2, 2500],
#  'отчитывать': [2, 2500],
#  '(ить': [2, 2220],
#  'закона)': [2, 2220],
#  '(рсв': [2, 1731],
#  '6-ндфл)': [2, 1731],
#  'ип-работодатель': [2, 1731],
#  'егрюла': [2, 2500],
#  'егрипа': [2, 2500],
#  'двухуровневый': [2, 2491],
#  '«красный': [2, 2500],
#  'белое»': [2, 2500],
#  '«додый': [2, 2500],
#  'пицца»': [2, 2500],
#  'пицца': [2, 2500],
#  'приём-увольнение': [2, 2500],
#  'lada': [2, 1023],
#  'алименты': [2, 2500],
#  'удерживаться': [2, 2500],
#  'авиасообщение': [2, 1598],
#  'кипр': [2, 1598],
#  'онлайн-касса': [2, 2500],
#  'касательно': [2, 2500],
#  'тёзка': [2, 1494],
#  'отчества)': [2, 1494],
#  'суперкомпьютер': [2, 2069],
#  '«т-платформы»': [2, 2069],
#  'подконтрольный': [2, 2238],
#  'упрощенок': [2, 2238],
#  'отгрузить': [2, 2432],
#  'пресекать': [2, 2500],
#  'фсбу?': [2, 2500],
#  '«чрезмерный': [2, 1385],
#  'здоровью!': [2, 1385],
#  'враг!»': [2, 1385],
#  '–31': [2, 2500],
#  'донецкий': [2, 1964],
#  'луганский': [2, 1964],
#  'договорник': [2, 2144],
#  'пароль': [2, 1740],
#  '«газпрома»': [2, 1644],
#  '5103': [2, 1644],
#  '200-210': [2, 2267],
#  'топ-5': [2, 2267],
#  'заморозка': [2, 1859],
#  '«госуслуг»': [2, 2257],
#  '121': [2, 2500],
#  'умерший': [2, 2409],
#  'джерси': [2, 1378],
#  'гознак': [2, 972],
#  'полиграфия': [2, 972],
#  'банкнот': [2, 972],
#  'марка': [2, 972],
#  '010722': [2, 2360],
#  '030723': [2, 2360],
#  '14072022': [2, 2500],
#  '№266-фз': [2, 2500],
#  'тренинг': [2, 1535],
#  'оксфордский': [2, 1505],
#  'сверхумный': [2, 1505],
#  'из-под': [2, 1505],
#  'фатальный': [2, 1505],
#  '442%': [2, 1855],
#  'медианный': [2, 1855],
#  'отпускной': [2, 2250],
#  'гасить': [2, 2449],
#  'госслужба': [2, 1645],
#  '920': [2, 2500],
#  'обновиться': [2, 2500],
#  'kb': [2, 986],
#  'euronet': [2, 986],
#  'классификатор': [2, 2102],
#  '01012022': [2, 2102],
#  'мусоровоз': [2, 2102],
#  'мошенничество': [2, 1610],
#  'фейковый': [2, 1610],
#  'интернет-площадка': [2, 1980],
#  'креатив': [2, 1980],
#  '«география»': [2, 1807],
#  'курортный': [2, 1196],
#  'кубань': [2, 1196],
#  'ставрополье': [2, 1196],
#  'алтайский': [2, 1196],
#  'вовлечение': [2, 2194],
#  'невостребованный': [2, 2194],
#  'сельхозземеля': [2, 2194],
#  'свериться': [2, 2194],
#  'пальмовый': [2, 1168],
#  'лазейка': [2, 1168],
#  'дедушке»': [2, 1360],
#  '«100': [2, 1360],
#  'км': [2, 1360],
#  'дороги»': [2, 1360],
#  'обособленный': [2, 1360],
#  'ос-09-3-1': [2, 1360],
#  'фиас': [2, 1360],
#  'ежеквартально': [2, 2298],
#  '(оквэда': [2, 930],
#  '45203)': [2, 930],
#  '«технический': [2, 930],
#  'автотранспортный': [2, 930],
#  'средств»': [2, 930],
#  'техобслуживание': [2, 930],
#  'неофициально': [2, 1323],
#  'raiffeisen': [2, 2122],
#  '«дочки»': [2, 2122],
#  'изымать': [2, 1514],
#  'астана': [2, 1514],
#  'поощрительный': [2, 1873],
#  'электросамокат': [2, 1654],
#  'пешеходный': [2, 1654],
#  'завозить': [2, 1239],
#  'парфюмерия': [2, 1239],
#  '«доходы»': [2, 1569],
#  'исчерпывающий': [2, 2000],
#  'рассрочка': [2, 2199],
#  'avaya': [2, 2197],
#  'возобновить': [2, 1191],
#  '(передаточный': [2, 1572],
#  'счет-фактура)': [2, 1572],
#  ...}

# %%
# normalizing
def normalize(trend):
    n1l = []
    n2l = []
    for k in trend:
        n1, n2 = trend[k]
        n1l.append(n1)
        n2l.append(n2)
    m1 = max(n1l)
    m2 = max(n2l)

    for k in trend:
        trend[k][0] = trend[k][0]/m1
        trend[k][1] = trend[k][1]/m2
    return trend

trend_out = normalize(trend_out)
trend_out_econ = normalize(trend_out_econ)
trend_out_bux = normalize(trend_out_bux)

# %%
trend_out_bux
# Out:
# {'кбк': [0.045454545454545456, 1.0],
#  'оквэда': [0.1590909090909091, 0.5484359233097881],
#  'ндс': [1.0, 0.2554980115154033],
#  'контрагент': [0.06818181818181818, 0.40598721829801543],
#  'ип': [0.5454545454545454, 0.4289261245950396],
#  'фсс': [0.20454545454545456, 0.4845834734835744],
#  'фсб': [0.1590909090909091, 0.3385469223007064],
#  'ндфл': [0.8409090909090909, 0.31608720912454513],
#  'кадровик': [0.1590909090909091, 0.30171543895055497],
#  'самозанятой': [0.4090909090909091, 0.23696602758156746],
#  'усн': [0.25, 0.43143289606458124],
#  'псн': [0.13636363636363635, 0.3816010763538513],
#  'онлайн-касса': [0.022727272727272728, 0.7805247225025227],
#  'аванс': [0.11363636363636363, 0.2865792129162462],
#  'гпх': [0.06818181818181818, 0.5739152371342079],
#  'нпд': [0.13636363636363635, 0.2973427514295325],
#  'реквизит': [0.06818181818181818, 0.4032963336696939],
#  'дивиденд': [0.09090909090909091, 0.25992263706693575],
#  'мрот': [0.09090909090909091, 0.24627901109989908],
#  'упд': [0.09090909090909091, 0.32328456104944503],
#  'коап': [0.022727272727272728, 0.46644803229061554],
#  'депозит': [0.13636363636363635, 0.44492095526404307],
#  'росстат': [0.09090909090909091, 0.2429364278506559],
#  'арендодатель': [0.022727272727272728, 0.3867305751765893],
#  'загранкомандировка': [0.022727272727272728, 0.15993945509586277],
#  'пбу': [0.045454545454545456, 0.20358224016145307],
#  'инвентаризация': [0.022727272727272728, 0.32820383451059537],
#  'акциз': [0.11363636363636363, 0.19283551967709384],
#  'документооборот': [0.09090909090909091, 0.17015640766902118],
#  'сбп': [0.045454545454545456, 0.21594349142280525],
#  'конвертация': [0.13636363636363635, 0.1296670030272452],
#  'эдо': [0.022727272727272728, 0.25],
#  'нерезидент': [0.11363636363636363, 0.18062563067608475],
#  'аудит': [0.09090909090909091, 0.1541372351160444],
#  'эцп': [0.022727272727272728, 0.2330978809283552],
#  'импортёр': [0.045454545454545456, 0.10280020181634712],
#  'эмитент': [0.1590909090909091, 0.19248234106962664],
#  'резидент': [0.06818181818181818, 0.2503363605785402],
#  'сальдо': [0.022727272727272728, 0.1869323915237134],
#  'инна': [0.06818181818181818, 0.2739656912209889],
#  'дисконт': [0.022727272727272728, 0.7505045408678103],
#  'сро': [0.045454545454545456, 0.09661957618567103]}

# %%
k_t = 1
k_econ = 3
k_bux = 5

trend_sum = {}
for k in trend_out:
    score = trend_out[k][0] * trend_out[k][1] * k_t
    trend_sum[k] = score
for k in trend_out_econ:
    score = trend_out_econ[k][0] * trend_out_econ[k][1] * k_econ
    trend_sum[k] = score
for k in trend_out_bux:
    score = trend_out_bux[k][0] * trend_out_bux[k][1] * k_bux
    trend_sum[k] = score

k_t = 1
k_econ = 8
k_bux = 2

trend_sum_dir = {}
for k in trend_out:
    score = trend_out[k][0] * trend_out[k][1] * k_t
    trend_sum_dir[k] = score
for k in trend_out_econ:
    score = trend_out_econ[k][0] * trend_out_econ[k][1] * k_econ
    trend_sum_dir[k] = score
for k in trend_out_bux:
    score = trend_out_bux[k][0] * trend_out_bux[k][1] * k_bux
    trend_sum_dir[k] = score

# %%
trend_sum
# Out:
# {'2023': 0.5424126315789474,
#  'мобилизация': 2.4932148470911426,
#  '2022': 0.5711739795918368,
#  'руб': 0.42341632653061223,
#  'мобилизовать': 0.4889800941915227,
#  'госдума': 0.28055918367346944,
#  'минфин': 0.38782320135118287,
#  'цб': 0.4738327827139477,
#  'из-за': 0.2700640721404841,
#  'ндс': 1.2774900575770165,
#  'ндфл': 1.3290030383645648,
#  'отсрочка': 0.3673469387755102,
#  'тыс': 0.3355925925925926,
#  'копа': 0.09667912087912087,
#  'фнс': 0.1783265306122449,
#  'налоговик': 0.1971918367346939,
#  'данные': 0.14579470899470898,
#  'млн': 0.13832049689440995,
#  'вычет': 0.1291948051948052,
#  '15': 0.11240578231292517,
#  'ип': 1.1697985216228353,
#  'михаил': 0.08367346938775509,
#  'премьер-министр': 0.08154285714285714,
#  '30': 0.10951428571428572,
#  'it-компания': 0.1654326530612245,
#  '2021': 0.11610300120048019,
#  'минцифра': 0.1836734693877551,
#  'минтруд': 0.07626122448979593,
#  'мишустин': 0.07486530612244899,
#  'самозанятой': 0.48470323823502437,
#  'алексей': 0.10726530612244899,
#  'владимир': 0.07348979591836734,
#  'нк': 0.07417551020408163,
#  'портал': 0.055926530612244896,
#  'минэкономразвития': 0.07142857142857142,
#  'уведомление': 0.1094997084548105,
#  'физлицо': 0.08633935860058309,
#  'путин': 0.12406938775510204,
#  'вебинар': 0.08738775510204082,
#  '«мир»': 0.06837142857142857,
#  '31': 0.062234693877551026,
#  'млрд': 0.10611616954474098,
#  'ипотека': 0.06575102040816327,
#  'сергей': 0.07322886297376094,
#  'малое': 0.12123673469387755,
#  'облагаться': 0.06594761904761903,
#  'пеня': 0.04564761904761905,
#  '«известиям»': 0.09785714285714286,
#  'среднее': 0.10949795918367349,
#  'госуслуга': 0.07688163265306122,
#  '10': 0.054595578231292526,
#  'мошенник': 0.08742040816326531,
#  'мораторий': 0.04583673469387755,
#  'днр': 0.07528163265306123,
#  'тк': 0.12244897959183673,
#  'приостановка': 0.1089469387755102,
#  'максим': 0.06753061224489795,
#  'александр': 0.09046122448979592,
#  '17': 0.06820816326530611,
#  '12': 0.06520964749536177,
#  'военкомат': 0.09043413729128014,
#  'платёжный': 0.04426419294990724,
#  '10%': 0.04080816326530612,
#  'лнр': 0.07191428571428571,
#  'аккредитация': 0.09217052154195012,
#  'казахстан': 0.05281795918367347,
#  'усн': 0.5392911200807265,
#  'лимит': 0.05882979591836735,
#  '16': 0.03884489795918367,
#  'трлн': 0.03352380952380952,
#  '0%': 0.03392489795918367,
#  'риа': 0.05371020408163265,
#  'вс': 0.061763265306122445,
#  'аккредитовать': 0.09528798185941044,
#  'пфр': 0.0933265306122449,
#  'профильный': 0.08108673469387755,
#  'бухучёт': 0.06733333333333334,
#  'маркетплейс': 0.0536281179138322,
#  '20%': 0.03693877551020408,
#  'иа': 0.03998775510204082,
#  'херсонский': 0.07344081632653061,
#  'запорожский': 0.07344081632653061,
#  'фсс': 0.49559673424456474,
#  'набиуллин': 0.04729795918367348,
#  'ккт': 0.049833236151603504,
#  '13': 0.05448163265306123,
#  'роструд': 0.038318367346938775,
#  'субсидия': 0.030375510204081635,
#  'центробанк': 0.029118367346938775,
#  'аудиторский': 0.031717784256559765,
#  'недружественный': 0.023938775510204083,
#  'рбк': 0.024473469387755103,
#  'regnum': 0.022510204081632658,
#  '21': 0.05790612244897959,
#  '27': 0.05360408163265305,
#  '100': 0.08163265306122448,
#  'турция': 0.027061224489795917,
#  'пресс-служба': 0.02681224489795918,
#  '22': 0.06700874635568513,
#  'эльвира': 0.04334285714285714,
#  '11': 0.034826822157434406,
#  'минпромторг': 0.031167346938775504,
#  'юань': 0.03426530612244898,
#  'чм': 0.03688571428571428,
#  'юрлицо': 0.02230204081632653,
#  'мосбиржа': 0.08163265306122448,
#  'вице-премьер': 0.019473469387755103,
#  'повыситься': 0.025355102040816323,
#  'it': 0.07142857142857142,
#  'контрактник': 0.07142857142857142,
#  '300': 0.07142857142857142,
#  'оквэда': 0.4362558480873314,
#  'бронь': 0.05961428571428571,
#  'банкомат': 0.07142857142857142,
#  'минобороны': 0.06722448979591836,
#  'фсб': 0.2692986881937437,
#  'кадровик': 0.24000091734703238,
#  'прожиточный': 0.044009523809523804,
#  'бренд': 0.03103673469387755,
#  'замглавы': 0.021783673469387754,
#  '2024': 0.030551020408163265,
#  'роскомнадзор': 0.03369387755102041,
#  'кадастровый': 0.041125714285714286,
#  'антон': 0.021526530612244896,
#  'белоруссия': 0.015551020408163266,
#  'эмитент': 0.15311095312356662,
#  'решетник': 0.013506122448979592,
#  'кабмин': 0.041804081632653055,
#  'андрей': 0.019142857142857142,
#  'ефс-1': 0.061224489795918366,
#  'сзв-тд': 0.061224489795918366,
#  'приостанавливаться': 0.05578367346938776,
#  'критически': 0.03486530612244898,
#  'соответствующий': 0.02039591836734694,
#  'рассылка': 0.05557142857142857,
#  '2025': 0.029081632653061223,
#  'проиндексировать': 0.025122448979591837,
#  'ифнс': 0.031983673469387755,
#  'ozon': 0.03372244897959183,
#  'wildberries': 0.04384081632653061,
#  'псн': 0.26018255205944407,
#  'нпд': 0.20273369415649942,
#  'ужесточить': 0.031204081632653063,
#  'приостановление': 0.02,
#  'крым': 0.02284408163265306,
#  'сверка': 0.026979591836734696,
#  'по-прежнему': 0.035457142857142854,
#  '400': 0.019575510204081634,
#  'депозит': 0.3033551967709385,
#  '28': 0.01626938775510204,
#  'сбербанк': 0.01648979591836735,
#  'минсельхоз': 0.01729795918367347,
#  'облагать': 0.01740816326530612,
#  'конвертация': 0.088409320245849,
#  'скорее': 0.021281632653061225,
#  'мсп': 0.02070612244897959,
#  'сазан': 0.035861224489795916,
#  'брокер': 0.013277551020408162,
#  'аусна': 0.014272653061224489,
#  'еаэс': 0.01733877551020408,
#  '23': 0.0526204081632653,
#  'зампред': 0.01883265306122449,
#  'пф': 0.03146938775510204,
#  '60': 0.05102040816326531,
#  'сво': 0.1595744680851064,
#  'увольнять': 0.05102040816326531,
#  'тд': 0.05102040816326531,
#  'бухгалтерия': 0.027804081632653063,
#  '30%': 0.04520408163265306,
#  'возобновление': 0.03196734693877551,
#  'заблокировать': 0.028404081632653063,
#  'главбух': 0.03548163265306122,
#  'кто-то': 0.02607482993197279,
#  'володин': 0.02451836734693878,
#  'санкционный': 0.015722448979591838,
#  '75%': 0.03316326530612245,
#  '6%': 0.03266122448979592,
#  'нетрудоспособность': 0.01842857142857143,
#  'аванс': 0.16282909824786718,
#  'избежание': 0.020918367346938773,
#  'минтранс': 0.016846938775510203,
#  'ооо': 0.020903061224489795,
#  'ст': 0.01633061224489796,
#  'злоумышленник': 0.019175510204081633,
#  'арендный': 0.013744897959183672,
#  'акциз': 0.10956563618016694,
#  'застройщик': 0.012685714285714286,
#  '14': 0.018134693877551022,
#  'нерезидент': 0.10262819924777541,
#  'основное': 0.011391836734693878,
#  'малоимущий': 0.03804591836734694,
#  'ндпить': 0.009959183673469388,
#  '20': 0.016020408163265307,
#  'моисеев': 0.013257142857142858,
#  'намерить': 0.011718367346938777,
#  'игорь': 0.020420408163265305,
#  'дмитрий': 0.049102040816326534,
#  'евросоюз': 0.008400000000000001,
#  'пресс-секретарь': 0.04081632653061224,
#  'подлежащее': 0.03649795918367347,
#  '50%': 0.03461632653061224,
#  'анонсировать': 0.04081632653061224,
#  'призывный': 0.0264,
#  'вячеслав': 0.030506122448979586,
#  '26': 0.028216326530612245,
#  '1с': 0.034848979591836735,
#  'приостанавливать': 0.03284081632653061,
#  'маркировка': 0.024914285714285715,
#  'санкт-петербург': 0.03236734693877551,
#  'фас': 0.01873877551020408,
#  'беременная': 0.04059591836734694,
#  'корректировка': 0.02533469387755102,
#  '15%': 0.03356734693877551,
#  'гибдд': 0.023497959183673468,
#  '55': 0.02944489795918367,
#  'беларусь': 0.02730612244897959,
#  'осаго': 0.02177142857142857,
#  'автовладелец': 0.02444489795918367,
#  'банкрот': 0.021053061224489796,
#  '200': 0.015114285714285714,
#  'плательщик': 0.02446938775510204,
#  'латвия': 0.020053061224489795,
#  'счёт-фактура': 0.022236734693877547,
#  'дивиденд': 0.11814665321224353,
#  'вакансия': 0.0195469387755102,
#  'мошеннический': 0.016375510204081633,
#  'учётный': 0.024191836734693876,
#  '1%': 0.018714285714285715,
#  'массово': 0.013061224489795917,
#  '25': 0.01953877551020408,
#  'ос': 0.02371836734693877,
#  'начисление': 0.022028571428571425,
#  'мрот': 0.11194500504540866,
#  '2019': 0.014791836734693876,
#  'отчитываться': 0.018020408163265306,
#  'фтс': 0.018514285714285712,
#  'упд': 0.14694752774974773,
#  'минприрода': 0.012416326530612245,
#  'россии»': 0.018285714285714284,
#  'софт': 0.015959183673469386,
#  'индексация': 0.013661224489795917,
#  'росстат': 0.11042564902302542,
#  'евгений': 0.027767346938775507,
#  'сбер': 0.01576326530612245,
#  'онлайн': 0.012514285714285712,
#  'армения': 0.014224489795918366,
#  'документооборот': 0.0773438216677369,
#  '70': 0.02146938775510204,
#  'бухотчётность': 0.013922448979591837,
#  'жкх': 0.008746938775510202,
#  'беспошлинный': 0.013604081632653059,
#  'ввоз': 0.037481632653061224,
#  'аудит': 0.070062379598202,
#  'наслать': 0.013326530612244897,
#  'социально-экономический': 0.011914285714285712,
#  'полис': 0.014632653061224488,
#  'рекордный': 0.015587755102040815,
#  'неквалифицированный': 0.007885714285714286,
#  'мвд': 0.009365986394557822,
#  'микрозаём': 0.007097959183673469,
#  '2023-2025': 0.009012244897959184,
#  'списывать': 0.016391836734693875,
#  'антимонопольный': 0.013251700680272108,
#  'telegram-канал': 0.014746938775510204,
#  'ук': 0.02406530612244898,
#  '«альфа-капитал»': 0.02406530612244898,
#  'тасс': 0.03197551020408163,
#  '«известий»': 0.011579591836734694,
#  '&gt;&gt;&gt;': 0.030877551020408157,
#  'лдпр': 0.01480408163265306,
#  'высокооплачиваемый': 0.011733333333333332,
#  'иван': 0.01229795918367347,
#  '"коммерсант"': 0.00610204081632653,
#  '50': 0.030612244897959183,
#  '65': 0.030612244897959183,
#  '195': 0.030612244897959183,
#  'призывник': 0.030612244897959183,
#  'начислить': 0.030612244897959183,
#  'грамотность': 0.017746938775510205,
#  '3517': 0.023416326530612246,
#  'стимулирование': 0.02219591836734694,
#  '182н': 0.030612244897959183,
#  'белгородский': 0.021893877551020405,
#  '(работа': 0.019685714285714286,
#  'контрагент': 0.13840473351068705,
#  'годность': 0.025314285714285716,
#  'анатолий': 0.02043673469387755,
#  'аксаков': 0.02043673469387755,
#  'начислять': 0.030612244897959183,
#  '70%': 0.017244897959183672,
#  '5%': 0.020493877551020407,
#  'потенциально': 0.030612244897959183,
#  '2026': 0.011191836734693877,
#  'максут': 0.030612244897959183,
#  'шадаев': 0.030612244897959183,
#  'получатель': 0.015902040816326533,
#  'it-специалист': 0.01739591836734694,
#  '46': 0.024151020408163262,
#  'экипировка': 0.01726122448979592,
#  '2014': 0.023322448979591837,
#  'всё-таки': 0.01780408163265306,
#  'распечатать': 0.026571428571428572,
#  'windows': 0.009955102040816326,
#  '2015': 0.030612244897959183,
#  '100%': 0.019583673469387754,
#  'прогул': 0.015183673469387754,
#  '(до': 0.02346938775510204,
#  '24': 0.02204489795918367,
#  'занятой': 0.018828571428571427,
#  'нотариальный': 0.030612244897959183,
#  'гпх': 0.1956529217502981,
#  'размещать': 0.011755102040816326,
#  'соцсеть': 0.013269387755102042,
#  'реквизит': 0.13748738647830472,
#  'альфа-банк': 0.017016326530612247,
#  'ольга': 0.009057142857142857,
#  'оформляться': 0.010595918367346939,
#  'мобилизационный': 0.018297959183673468,
#  'аннулировать': 0.021359183673469388,
#  '000': 0.019293877551020407,
#  'поменяться': 0.024273469387755098,
#  'недобросовестный': 0.014012244897959183,
#  'кассовый': 0.021946938775510204,
#  'взимание': 0.009959183673469388,
#  'оспорить': 0.018281632653061222,
#  'травматизм': 0.017293877551020406,
#  'мойка': 0.008693877551020407,
#  'грузия': 0.01136734693877551,
#  'подорожать': 0.014542857142857144,
#  'программно-аппаратный': 0.013775510204081633,
#  'фискальный': 0.010563265306122447,
#  'неработающий': 0.013016326530612245,
#  'безотзывный': 0.013355102040816327,
#  'списание': 0.010928571428571428,
#  '500': 0.011187755102040816,
#  '«единый': 0.014812244897959185,
#  'послабление': 0.024673469387755102,
#  'ес': 0.01540408163265306,
#  '«клерке»': 0.014379591836734693,
#  'toyota': 0.010240816326530613,
#  '149': 0.012277551020408162,
#  'выкупить': 0.010828571428571429,
#  'apple': 0.011865306122448979,
#  'ретейлер': 0.012289795918367347,
#  '2%': 0.01306530612244898,
#  'мсфо': 0.010297959183673468,
#  '(ifrs)': 0.010297959183673468,
#  'ежемесячный': 0.007469387755102041,
#  'узбекистан': 0.01123265306122449,
#  '8%': 0.015183673469387754,
#  '2020': 0.0103265306122449,
#  'тестировать': 0.009836734693877552,
#  'выемка': 0.011897959183673468,
#  'дистанционный': 0.008253061224489796,
#  'безналичный': 0.01446938775510204,
#  'доначисление': 0.013755102040816326,
#  'разморозка': 0.009459183673469387,
#  'криптовалюта': 0.008322448979591836,
#  'субсидировать': 0.008330612244897959,
#  'айтишник': 0.010314285714285715,
#  'евразийский': 0.01116734693877551,
#  'трата': 0.015840816326530616,
#  '22%': 0.010346938775510205,
#  'заём': 0.008522448979591837,
#  'системообразующий': 0.009604081632653062,
#  'мспрф': 0.00933469387755102,
#  'безработный': 0.014151020408163266,
#  'уволиться': 0.01203265306122449,
#  'истекать': 0.007918367346938775,
#  'прорабатывать': 0.008424489795918368,
#  'уведомить': 0.010138775510204081,
#  'рейтинговый': 0.009191836734693875,
#  'спрогнозировать': 0.013032653061224489,
#  'драгметалл': 0.006359183673469388,
#  'ребрендинг': 0.006865306122448979,
#  'втб': 0.006824489795918367,
#  '17%': 0.00930204081632653,
#  '40': 0.017236734693877553,
#  'расписка': 0.005208163265306123,
#  'госрегистрация': 0.005579591836734695,
#  'авто': 0.007395918367346939,
#  '1500': 0.0040122448979591835,
#  'миронов': 0.011257142857142858,
#  'ввп': 0.00633061224489796,
#  'страхователь': 0.004436734693877551,
#  'sputnik': 0.009387755102040816,
#  'резидент': 0.08534194110632053,
#  'промышленник': 0.011612244897959183,
#  'пленарный': 0.01445714285714286,
#  'минэкономики': 0.004506122448979592,
#  '«вечерня': 0.030612244897959183,
#  'исчислить': 0.006171428571428572,
#  'б/с': 0.003955102040816327,
#  'superjob': 0.02451428571428571,
#  'rt': 0.010155102040816325,
#  'еврокомиссия': 0.005583673469387755,
#  'новостройка': 0.02100612244897959,
#  '"каникулы"': 0.008930612244897959,
#  'импортозамещение': 0.007003985710386825,
#  'незаконно': 0.011453061224489797,
#  'инна': 0.09339739473442804,
#  'белоус': 0.005240816326530612,
#  '"о': 0.01633469387755102,
#  'макроэкономический': 0.013616326530612243,
#  'краткосрочный': 0.017285714285714286,
#  'мид': 0.02040816326530612,
#  'обнародовать': 0.02040816326530612,
#  '712': 0.02040816326530612,
#  '«сведение': 0.02040816326530612,
#  'персучёт': 0.02040816326530612,
#  'производстве»': 0.02040816326530612,
#  'вели': 0.02040816326530612,
#  'очный': 0.02040816326530612,
#  'очно-заочный': 0.02040816326530612,
#  'упрощать': 0.02040816326530612,
#  'повторно': 0.02040816326530612,
#  'кбк': 0.2272727272727273,
#  '102': 0.019812244897959182,
#  'ростуризм': 0.018146938775510203,
#  'гособоронзаказ': 0.02040816326530612,
#  'неявка': 0.02040816326530612,
#  'оставление': 0.02040816326530612,
#  'услуг)': 0.016518367346938775,
#  'росстандарт': 0.02040816326530612,
#  'фитнес-клуб': 0.016983673469387756,
#  '«у': 0.018061224489795916,
#  'спецоценка': 0.017330612244897958,
#  'нанимать': 0.018661224489795916,
#  'ратификация': 0.009355102040816325,
#  'медиа': 0.02040816326530612,
#  'туроператор': 0.009020408163265305,
#  'майнинга': 0.010644897959183672,
#  'договорный': 0.017457142857142855,
#  'прослеживаемость': 0.02040816326530612,
#  'штрафовать': 0.02040816326530612,
#  'запросить': 0.009261224489795918,
#  '$400': 0.005420408163265306,
#  'инвестировать': 0.016359183673469387,
#  'нпф': 0.02040816326530612,
#  'иванович': 0.02040816326530612,
#  'ikea': 0.02040816326530612,
#  'осный': 0.015653061224489794,
#  'капремонт': 0.02040816326530612,
#  'фссп': 0.009330612244897958,
#  'водительский': 0.013583673469387754,
#  'роды': 0.013987755102040816,
#  'пересчитывать': 0.015742857142857142,
#  '188': 0.017987755102040814,
#  '250': 0.01964081632653061,
#  'снилс': 0.018457142857142856,
#  'приёмка': 0.0195469387755102,
#  'шенгенский': 0.011473469387755102,
#  'матвиенко': 0.01599591836734694,
#  'нецелесообразный': 0.017379591836734692,
#  '1/3': 0.017069387755102042,
#  'даниил': 0.009922448979591837,
#  'егоров': 0.009922448979591837,
#  'проактивный': 0.01396326530612245,
#  '«этый': 0.01306938775510204,
#  'рассылать': 0.019477551020408164,
#  'подраздел': 0.018922448979591836,
#  '41%': 0.005657142857142857,
#  'довольствие': 0.02040816326530612,
#  '(переть': 0.011763265306122449,
#  'пристав': 0.01183265306122449,
#  'дорогой': 0.01400408163265306,
#  'вредить': 0.009820408163265305,
#  'прослеживать': 0.014763265306122448,
#  'баталин': 0.0073346938775510195,
#  'озвучить': 0.006889795918367346,
#  'топ': 0.014371428571428571,
#  'ростов-на-дону': 0.013620408163265305,
#  'продлевать': 0.009816326530612244,
#  'накопительный': 0.012167346938775508,
#  'adidas': 0.01237142857142857,
#  'неуплата': 0.012277551020408162,
#  'тимбилдинг': 0.013248979591836733,
#  'тульский': 0.010799999999999999,
#  'возмещать': 0.00923265306122449,
#  '(сфр)': 0.020065306122448976,
#  'ежемесячно': 0.01274285714285714,
#  'штрихкод': 0.01177142857142857,
#  'bank': 0.012685714285714286,
#  'гарантийный': 0.013420408163265304,
#  'ввозить': 0.007530612244897959,
#  '«на': 0.007481632653061223,
#  'профзаболевание': 0.012608163265306121,
#  'разовый': 0.010555102040816326,
#  '26%': 0.010081632653061223,
#  'поддельный': 0.02034285714285714,
#  'несвоевременный': 0.02040816326530612,
#  'загранпаспорт': 0.008677551020408163,
#  'комплектующие': 0.006726530612244898,
#  '(противодействия)': 0.01920816326530612,
#  'ратифицировать': 0.004387755102040816,
#  'пилотный': 0.010057142857142857,
#  'банкинг': 0.010595918367346939,
#  '864': 0.00853877551020408,
#  'гоз': 0.011134693877551019,
#  'гис': 0.007404081632653061,
#  'графа': 0.015616326530612243,
#  '135': 0.005338775510204081,
#  'спецоперация': 0.009632653061224489,
#  'легализовать': 0.0076326530612244895,
#  'въезжать': 0.012159183673469387,
#  'трудоустройство': 0.008791836734693878,
#  'кризисный': 0.012040816326530611,
#  'общепит': 0.008391836734693877,
#  '350': 0.012122448979591836,
#  'суточный': 0.009922448979591837,
#  'партнёрский': 0.011289795918367346,
#  'активизироваться': 0.017289795918367344,
#  'визовый': 0.00957142857142857,
#  'выгодоприобретатель': 0.016028729202762007,
#  'санаторно-курортный': 0.010612244897959183,
#  'п9': 0.008122448979591837,
#  'собянин': 0.011081632653061224,
#  'окз': 0.009726530612244898,
#  'черногория': 0.0076326530612244895,
#  '6/2020': 0.009093877551020407,
#  'автоконцерн': 0.00803265306122449,
#  '05': 0.011195918367346937,
#  'пп': 0.007885714285714286,
#  'it-бизнес': 0.009061224489795917,
#  'стартап': 0.013589432592141761,
#  'пбу': 0.04626869094578479,
#  'шойгу': 0.01277142857142857,
#  'допуск': 0.006685714285714285,
#  'вечером': 0.008175510204081632,
#  'мессенджер': 0.00770204081632653,
#  '25/2018': 0.01089795918367347,
#  'ппа': 0.008877551020408162,
#  '«об': 0.007799999999999999,
#  '76%': 0.008163265306122448,
#  'тратиться': 0.007710204081632653,
#  'карточный': 0.02040816326530612,
#  'revolut': 0.009469387755102041,
#  'подключиться': 0.008448979591836733,
#  'продление': 0.006187755102040816,
#  '(иис)': 0.005889795918367347,
#  'возгорание': 0.007791836734693876,
#  'рсв': 0.01743673469387755,
#  'дебетовый': 0.008440816326530612,
#  'кешбэк': 0.0069551020408163255,
#  'поблажка': 0.007583673469387754,
#  'адвокатский': 0.008159183673469387,
#  'учете»': 0.009024489795918366,
#  'совершенствовать': 0.009493877551020408,
#  'сбп': 0.04907806623245574,
#  'зачислить': 0.006089795918367347,
#  '«кнопка»': 0.009306122448979591,
#  'смартфон': 0.007946938775510204,
#  'предупредительный': 0.00583673469387755,
#  '46%': 0.006248979591836735,
#  'предзаказ': 0.007616326530612244,
#  '990': 0.007616326530612244,
#  '60%': 0.006832653061224489,
#  'непристегнуть': 0.009126530612244896,
#  'внереализационный': 0.00843673469387755,
#  'partners': 0.0066489795918367334,
#  'fix': 0.006697959183673469,
#  'price': 0.006697959183673469,
#  '52': 0.006665306122448979,
#  'росреестр': 0.004518367346938775,
#  'вредоносный': 0.006032653061224489,
#  '859%': 0.006493877551020408,
#  'выездной': 0.006493877551020408,
#  'мфц': 0.006244897959183673,
#  'силуановый': 0.006310204081632652,
#  'провайдер': 0.0049387755102040815,
#  'онлайн-школа': 0.007310204081632653,
#  'графика': 0.011620408163265306,
#  'гир': 0.006624489795918367,
#  'бо': 0.006624489795918367,
#  'товаропроизводитель': 0.005232653061224489,
#  '€1000': 0.006591836734693877,
#  'хозпостройка': 0.008106122448979592,
#  '(центробанк': 0.007053061224489796,
#  'цб)': 0.007053061224489796,
#  '«двигать»': 0.007053061224489796,
#  '4%': 0.004648979591836734,
#  '«клеркпремиум»': 0.005881632653061224,
#  '29': 0.008518367346938775,
#  'финляндия': 0.006191836734693877,
#  '9%': 0.005473469387755101,
#  'нк)': 0.006408163265306122,
#  'аутсорсинг': 0.006473469387755101,
#  '«клерк»': 0.00703265306122449,
#  '124%': 0.00536734693877551,
#  'предпенсионер': 0.006138775510204081,
#  '2018': 0.006314285714285714,
#  'appstore': 0.006142857142857142,
#  'киргизия': 0.006987755102040815,
#  'нежилой': 0.00620408163265306,
#  'неограниченный': 0.005432653061224489,
#  '3%': 0.0068081632653061224,
#  'удалённый': 0.005914285714285714,
#  'экстренный': 0.018722448979591834,
#  'реорганизовать': 0.005416326530612245,
#  'лизинговый': 0.004159183673469387,
#  'товарооборот': 0.005999999999999999,
#  'приравниваться': 0.006187755102040816,
#  'благотворительность': 0.004820408163265306,
#  '1000': 0.008089795918367346,
#  'рецептурный': 0.004514285714285714,
#  'топ-15': 0.005971428571428571,
#  'просрочить': 0.005685714285714285,
#  'вина': 0.004126530612244898,
#  'запчасть': 0.004648979591836734,
#  'ндд': 0.004122448979591836,
#  'импортёр': 0.023363682230987982,
#  'vk': 0.0056408163265306115,
#  'club': 0.006351020408163264,
#  'фз': 0.004812244897959184,
#  'татарстан': 0.0058,
#  'поощрение': 0.003922448979591837,
#  'капиталовложение': 0.003922448979591837,
#  'дилерский': 0.004310204081632653,
#  'подмосковье': 0.005587755102040816,
#  'депозитарий': 0.02040816326530612,
#  'наравне': 0.004306122448979591,
#  'госкомпания': 0.005020408163265305,
#  'денис': 0.0043918367346938774,
#  'мантур': 0.0043918367346938774,
#  '(от': 0.004371428571428571,
#  'госзакупка': 0.0048734693877551015,
#  '65%': 0.004999999999999999,
#  '56': 0.012975510204081633,
#  'mazda': 0.004853061224489795,
#  'просрочка': 0.004408163265306122,
#  'коронавирус': 0.0038734693877551015,
#  'mazars': 0.005424489795918366,
#  'слиток': 0.004583673469387754,
#  'проинформировать': 0.003208163265306122,
#  'отзывный': 0.003208163265306122,
#  'qiwi': 0.004506122448979592,
#  '32%': 0.004869387755102041,
#  '557': 0.004795918367346938,
#  'восстанавливаться': 0.004893877551020408,
#  'иис': 0.004840816326530612,
#  'unionpay': 0.004142857142857143,
#  '05%': 0.004163265306122449,
#  '24%': 0.0036653061224489795,
#  'некоммерческий': 0.003930612244897959,
#  'перераспределить': 0.0032367346938775507,
#  'экспортёр': 0.006608163265306121,
#  'испытательный': 0.0069551020408163255,
#  'зарегистрироваться': 0.006285714285714285,
#  'москвы»': 0.009975510204081632,
#  'рублёвый': 0.02040816326530612,
#  'депозитарный': 0.0031224489795918364,
#  'замедлиться': 0.0028816326530612243,
#  '(на': 0.009134693877551019,
#  'ужесточение': 0.02040816326530612,
#  'базисный': 0.013546938775510203,
#  'джиоев': 0.010061224489795918,
#  'аналитика': 0.02040816326530612,
#  '134': 0.003922448979591837,
#  '«интерфакс»': 0.005832653061224489,
#  'срзп': 0.007248979591836734,
#  '23%': 0.0046326530612244895,
#  '"согласие"': 0.02040816326530612,
#  'баррель': 0.009812244897959182,
#  'инвестирование': 0.012914285714285713,
#  'мск': 0.0044571428571428574,
#  '«деловой': 0.004510204081632652,
#  'коррекция': 0.02040816326530612,
#  'неприменение': 0.00924081632653061,
#  'жилищно-коммунальный': 0.009559183673469387,
#  'скупка': 0.004889795918367346,
#  'упростить': 0.007265306122448979,
#  '«этажи»': 0.016302040816326527,
#  '(вэф)': 0.004314285714285714,
#  'ernst': 0.005183673469387755,
#  '&amp;': 0.005183673469387755,
#  'young': 0.005183673469387755,
#  '2030': 0.0024653061224489793,
#  'предусмотренный': 0.006702040816326531,
#  'пропорционально': 0.009330612244897958,
#  'зампредседателя': 0.02040816326530612,
#  'совфеда': 0.014751020408163264,
#  'тренд': 0.005122448979591836,
#  'краснов': 0.0034408163265306118,
#  'bloomberg': 0.009840816326530612,
#  'москвой»': 0.02040816326530612,
#  'перерасчёт': 0.02040816326530612,
#  'пассив': 0.018351020408163263,
#  'взыскать': 0.003489795918367347,
#  'недоимка': 0.003489795918367347,
#  'леонид': 0.003755102040816326,
#  'горнина': 0.003755102040816326,
#  '«работару»': 0.0073346938775510195,
#  'вразрез': 0.012595918367346937,
#  'выманивание': 0.0046693877551020405,
#  'инфляционный': 0.006848979591836734,
#  '"прайм"': 0.006616326530612244,
#  '19': 0.005040816326530612,
#  'карантин': 0.012065306122448978,
#  'денежно-кредитный': 0.012440816326530612,
#  'опек': 0.002636734693877551,
#  'взаимозачёт': 0.0036163265306122447,
#  '2023–2025': 0.006061224489795918,
#  'стойкость': 0.02040816326530612,
#  'чебесков': 0.0030326530612244896,
#  'аудиторов»': 0.008016326530612244,
#  'zoom': 0.005293877551020408,
#  '(мск)': 0.005959183673469387,
#  'оговорить': 0.02034285714285714,
#  'трёхлетний': 0.003257142857142857,
#  'стратег': 0.02040816326530612,
#  'бахтин': 0.02040816326530612,
#  '19%': 0.003808163265306122,
#  '“ъ”': 0.003420408163265306,
#  '«известия»': 0.020163265306122446,
#  'наталья': 0.002877551020408163,
#  'дольщик': 0.0031428571428571426,
#  'антироссийский': 0.005240816326530611,
#  'законодательно': 0.0027959183673469386,
#  'новшество': 0.0036448979591836733,
#  'замруководитель': 0.0026448979591836732,
#  'артём': 0.007306122448979591,
#  'потребкредит': 0.0030163265306122444,
#  'фиксация': 0.017734693877551017,
#  'ру»': 0.01450204081632653,
#  '2016': 0.0037673469387755096,
#  'нина': 0.004146938775510204,
#  'останин': 0.004146938775510204,
#  'донбасс': 0.00413469387755102,
#  'владислав': 0.008742857142857142,
#  'суверенный': 0.004608163265306122,
#  'корректировать': 0.002759183673469387,
#  'ускоренный': 0.011122448979591837,
#  'нацвалюта': 0.004261224489795918,
#  '(цмакп)': 0.009077551020408163,
#  'россии"': 0.0028693877551020405,
#  '22h2': 0.0037591836734693876,
#  'перечисление': 0.005379591836734693,
#  'смягчить': 0.02040816326530612,
#  'ек': 0.0035673469387755103,
#  'заботкин': 0.02040816326530612,
#  'укрепиться': 0.00533469387755102,
#  '32': 0.006657142857142856,
#  'клиринговый': 0.02040816326530612,
#  '(нкц)': 0.02040816326530612,
#  'нкц': 0.02040816326530612,
#  'сро': 0.02195899458765251,
#  'аас': 0.0031265306122448978,
#  'валерий': 0.006595918367346938,
#  '"госуслуги"': 0.006832653061224489,
#  'рубля)': 0.02040816326530612,
#  'головченко': 0.002338775510204081,
#  'коксоваться': 0.001914285714285714,
#  '2514': 0.003763265306122449,
#  'срочник': 0.01020408163265306,
#  'сержантский': 0.01020408163265306,
#  'австрия': 0.01020408163265306,
#  '2609': 0.01020408163265306,
#  'гигиена': 0.01020408163265306,
#  'соцстрахование': 0.01020408163265306,
#  'надбавка': 0.01020408163265306,
#  'георгиевский': 0.01020408163265306,
#  'высококвалифицированный': 0.01020408163265306,
#  'неправомерно': 0.01020408163265306,
#  '№7': 0.01020408163265306,
#  '10-11': 0.006959183673469388,
#  'обществознание': 0.006959183673469388,
#  'спальная': 0.01020408163265306,
#  'термобельё': 0.01020408163265306,
#  '10-20%': 0.01020408163265306,
#  'платёжка': 0.01020408163265306,
#  'октмый': 0.01020408163265306,
#  '«налоговый': 0.01020408163265306,
#  'тайна»': 0.01020408163265306,
#  'интригующий': 0.009342857142857142,
#  'клерк': 0.009342857142857142,
#  'мерч': 0.009342857142857142,
#  'толстовка': 0.009342857142857142,
#  'принтом': 0.009342857142857142,
#  'стиль!': 0.009342857142857142,
#  'гладков': 0.01020408163265306,
#  'заговаривать': 0.01020408163265306,
#  'ужесточать': 0.01020408163265306,
#  'самовольный': 0.01020408163265306,
#  'дезертирство': 0.01020408163265306,
#  'счетно-сортировальный': 0.01020408163265306,
#  'валидатор': 0.01020408163265306,
#  '115-фз': 0.01020408163265306,
#  'него?': 0.01020408163265306,
#  'отчетностью?': 0.01020408163265306,
#  '«новое': 0.01020408163265306,
#  'люди»': 0.01020408163265306,
#  'решетников': 0.01020408163265306,
#  'скан': 0.01020408163265306,
#  'разбогатеть': 0.00889795918367347,
#  'iт-компания': 0.01020408163265306,
#  'привлекаться': 0.01020408163265306,
#  'брифинг': 0.01020408163265306,
#  'специальности»': 0.01020408163265306,
#  '40-50%': 0.006779591836734693,
#  'медучреждение': 0.01020408163265306,
#  'говорящий': 0.01020408163265306,
#  'квд': 0.01020408163265306,
#  'радикулит': 0.01020408163265306,
#  'сзв-стаж': 0.01020408163265306,
#  'безвизовый': 0.01020408163265306,
#  'сторонний': 0.01020408163265306,
#  'кудрин': 0.01020408163265306,
#  '«яндекс»': 0.01020408163265306,
#  'увозить': 0.01020408163265306,
#  '«кадровый': 0.01020408163265306,
#  'дырами»': 0.01020408163265306,
#  'работник-мужчина': 0.01020408163265306,
#  '«эвакуировали»': 0.01020408163265306,
#  'iт': 0.01020408163265306,
#  '(атор)': 0.0054571428571428575,
#  '205': 0.01020408163265306,
#  'якутия': 0.01020408163265306,
#  'авдонин': 0.01020408163265306,
#  'авиабилет': 0.00783673469387755,
#  'хождение': 0.008118367346938774,
#  '44-фз': 0.01020408163265306,
#  '25-го': 0.01020408163265306,
#  '28-быть': 0.01020408163265306,
#  'студент-очник': 0.01020408163265306,
#  'магистратура': 0.01020408163265306,
#  'заочный': 0.01020408163265306,
#  '$100': 0.004191836734693877,
#  '«бумажный': 0.01020408163265306,
#  'привычки»': 0.01020408163265306,
#  'файл': 0.01020408163265306,
#  'невыход': 0.007795918367346938,
#  'образцово': 0.005999999999999999,
#  'раскритиковать': 0.007583673469387754,
#  'иванов': 0.01020408163265306,
#  'анна': 0.01020408163265306,
#  'абрамович': 0.01020408163265306,
#  'изольда': 0.01020408163265306,
#  'призадуматься': 0.01020408163265306,
#  'mcdonald’s': 0.008546938775510203,
#  '3-ндфл': 0.01020408163265306,
#  '13%': 0.01020408163265306,
#  'разворачивать': 0.01020408163265306,
#  'репатриация': 0.01020408163265306,
#  'великобритания': 0.0057061224489795915,
#  'microsoft': 0.0061959183673469375,
#  'раскусить': 0.01020408163265306,
#  'разыграть': 0.01020408163265306,
#  'микроэлектроника': 0.0075673469387755096,
#  'нуждаемость': 0.01020408163265306,
#  'маркетплейс?': 0.01020408163265306,
#  '15%)': 0.01020408163265306,
#  'лесопромышленный': 0.01020408163265306,
#  'переориентация': 0.01020408163265306,
#  'спч': 0.01020408163265306,
#  'точен': 0.01020408163265306,
#  'взыскивать': 0.008946938775510204,
#  'внесудебный': 0.008946938775510204,
#  'летательный': 0.01020408163265306,
#  'дтп': 0.01020408163265306,
#  '6038-у': 0.01020408163265306,
#  'нововведение': 0.01010204081632653,
#  'прибалтийский': 0.006220408163265306,
#  'mango': 0.01020408163265306,
#  'zara': 0.01020408163265306,
#  'коворкинг': 0.008257142857142857,
#  'золотовалютный': 0.004897959183673469,
#  'бережливый': 0.008506122448979591,
#  'финорганизация': 0.01020408163265306,
#  'бизнес-омбудсмен': 0.006302040816326531,
#  '«забизнесрф»': 0.006302040816326531,
#  'элина': 0.006302040816326531,
#  'сидоренко': 0.006302040816326531,
#  '136': 0.0059469387755102035,
#  'полмесяца': 0.0059469387755102035,
#  '(без': 0.004375510204081633,
#  'заявлений)': 0.004375510204081633,
#  'подмога': 0.009808163265306123,
#  'напрягаться': 0.009808163265306123,
#  'зачем?': 0.009808163265306123,
#  'хотите?»': 0.009808163265306123,
#  'неполученный': 0.01020408163265306,
#  'отчитывать': 0.01020408163265306,
#  '(ить': 0.009061224489795917,
#  'закона)': 0.009061224489795917,
#  '(рсв': 0.007065306122448979,
#  '6-ндфл)': 0.007065306122448979,
#  'ип-работодатель': 0.007065306122448979,
#  'егрюла': 0.01020408163265306,
#  'егрипа': 0.01020408163265306,
#  'двухуровневый': 0.01016734693877551,
#  '«красный': 0.01020408163265306,
#  'белое»': 0.01020408163265306,
#  '«додый': 0.01020408163265306,
#  'пицца»': 0.01020408163265306,
#  'пицца': 0.01020408163265306,
#  'приём-увольнение': 0.01020408163265306,
#  'lada': 0.004175510204081632,
#  'алименты': 0.01020408163265306,
#  'удерживаться': 0.01020408163265306,
#  'авиасообщение': 0.006522448979591836,
#  'кипр': 0.006522448979591836,
#  'онлайн-касса': 0.08869599119346849,
#  'касательно': 0.01020408163265306,
#  'тёзка': 0.006097959183673469,
#  'отчества)': 0.006097959183673469,
#  'суперкомпьютер': 0.008444897959183673,
#  '«т-платформы»': 0.008444897959183673,
#  'подконтрольный': 0.009134693877551019,
#  'упрощенок': 0.009134693877551019,
#  'отгрузить': 0.009926530612244897,
#  'пресекать': 0.01020408163265306,
#  'фсбу?': 0.01020408163265306,
#  '«чрезмерный': 0.005653061224489796,
#  'здоровью!': 0.005653061224489796,
#  'враг!»': 0.005653061224489796,
#  '–31': 0.01020408163265306,
#  'донецкий': 0.008016326530612244,
#  'луганский': 0.008016326530612244,
#  'договорник': 0.008751020408163265,
#  'пароль': 0.007102040816326529,
#  '«газпрома»': 0.006710204081632652,
#  '5103': 0.006710204081632652,
#  '200-210': 0.009253061224489796,
#  'топ-5': 0.009253061224489796,
#  'заморозка': 0.007587755102040816,
#  '«госуслуг»': 0.009212244897959184,
#  '121': 0.01020408163265306,
#  'умерший': 0.00983265306122449,
#  'джерси': 0.0056244897959183675,
#  'гознак': 0.00396734693877551,
#  'полиграфия': 0.00396734693877551,
#  'банкнот': 0.00396734693877551,
#  'марка': 0.00396734693877551,
#  '010722': 0.009632653061224489,
#  '030723': 0.009632653061224489,
#  '14072022': 0.01020408163265306,
#  '№266-фз': 0.01020408163265306,
#  'тренинг': 0.006265306122448979,
#  'оксфордский': 0.006142857142857142,
#  'сверхумный': 0.006142857142857142,
#  'из-под': 0.006142857142857142,
#  'фатальный': 0.006142857142857142,
#  '442%': 0.007571428571428571,
#  'медианный': 0.007571428571428571,
#  'отпускной': 0.009183673469387754,
#  'гасить': 0.009995918367346939,
#  'госслужба': 0.006714285714285714,
#  '920': 0.01020408163265306,
#  'обновиться': 0.01020408163265306,
#  'kb': 0.004024489795918367,
#  'euronet': 0.004024489795918367,
#  'классификатор': 0.008579591836734693,
#  '01012022': 0.008579591836734693,
#  'мусоровоз': 0.008579591836734693,
#  'мошенничество': 0.006571428571428571,
#  'фейковый': 0.006571428571428571,
#  'интернет-площадка': 0.008081632653061225,
#  'креатив': 0.008081632653061225,
#  '«география»': 0.007375510204081632,
#  'курортный': 0.004881632653061224,
#  'кубань': 0.004881632653061224,
#  'ставрополье': 0.004881632653061224,
#  'алтайский': 0.004881632653061224,
#  'вовлечение': 0.008955102040816326,
#  'невостребованный': 0.008955102040816326,
#  'сельхозземеля': 0.008955102040816326,
#  'свериться': 0.008955102040816326,
#  'пальмовый': 0.00476734693877551,
#  'лазейка': 0.00476734693877551,
#  'дедушке»': 0.005551020408163266,
#  '«100': 0.005551020408163266,
#  'км': 0.005551020408163266,
#  'дороги»': 0.005551020408163266,
#  'обособленный': 0.005551020408163266,
#  'ос-09-3-1': 0.005551020408163266,
#  'фиас': 0.005551020408163266,
#  'ежеквартально': 0.009379591836734693,
#  '(оквэда': 0.0037959183673469386,
#  '45203)': 0.0037959183673469386,
#  '«технический': 0.0037959183673469386,
#  'автотранспортный': 0.0037959183673469386,
#  'средств»': 0.0037959183673469386,
#  'техобслуживание': 0.0037959183673469386,
#  'неофициально': 0.005399999999999999,
#  'raiffeisen': 0.008661224489795918,
#  '«дочки»': 0.008661224489795918,
#  'изымать': 0.006179591836734694,
#  'астана': 0.006179591836734694,
#  'поощрительный': 0.007644897959183673,
#  'электросамокат': 0.006751020408163264,
#  'пешеходный': 0.006751020408163264,
#  'завозить': 0.005057142857142856,
#  'парфюмерия': 0.005057142857142856,
#  '«доходы»': 0.006404081632653061,
#  'исчерпывающий': 0.008163265306122448,
#  'рассрочка': 0.01438073256502393,
#  'avaya': 0.00896734693877551,
#  'возобновить': 0.004861224489795918,
#  '(передаточный': 0.006416326530612244,
#  'счет-фактура)': 0.006416326530612244,
#  ...}

# %%
# to file
def save(trend, name='trend_words.csv'):
    words = [w[0] for w in list(trend.items())]
    num1 = [w[1][0] for w in list(trend.items())]
    num2 = [w[1][1] for w in list(trend.items())]

    df = pd.DataFrame({'word': words, 'num': num1, 'view': num2})
    df.to_csv(name)

save(trend_out, name='trend_words.csv')
save(trend_out_bux, name='trend_words_bux.csv')
save(trend_out_econ, name='trend_words_econ.csv')

# %%
trend_sum_dir
# Out:
# {'2023': 0.5424126315789474,
#  'мобилизация': 6.648572925576381,
#  '2022': 0.5711739795918368,
#  'руб': 0.42341632653061223,
#  'мобилизовать': 0.4889800941915227,
#  'госдума': 0.28055918367346944,
#  'минфин': 1.0341952036031543,
#  'цб': 1.2635540872371938,
#  'из-за': 0.2700640721404841,
#  'ндс': 0.5109960230308066,
#  'ндфл': 0.5316012153458259,
#  'отсрочка': 0.3673469387755102,
#  'тыс': 0.3355925925925926,
#  'копа': 0.09667912087912087,
#  'фнс': 0.1783265306122449,
#  'налоговик': 0.1971918367346939,
#  'данные': 0.14579470899470898,
#  'млн': 0.13832049689440995,
#  'вычет': 0.1291948051948052,
#  '15': 0.11240578231292517,
#  'ип': 0.46791940864913406,
#  'михаил': 0.08367346938775509,
#  'премьер-министр': 0.08154285714285714,
#  '30': 0.10951428571428572,
#  'it-компания': 0.1654326530612245,
#  '2021': 0.11610300120048019,
#  'минцифра': 0.1836734693877551,
#  'минтруд': 0.07626122448979593,
#  'мишустин': 0.07486530612244899,
#  'самозанятой': 0.19388129529400974,
#  'алексей': 0.10726530612244899,
#  'владимир': 0.07348979591836734,
#  'нк': 0.07417551020408163,
#  'портал': 0.055926530612244896,
#  'минэкономразвития': 0.07142857142857142,
#  'уведомление': 0.1094997084548105,
#  'физлицо': 0.08633935860058309,
#  'путин': 0.12406938775510204,
#  'вебинар': 0.08738775510204082,
#  '«мир»': 0.06837142857142857,
#  '31': 0.062234693877551026,
#  'млрд': 0.10611616954474098,
#  'ипотека': 0.06575102040816327,
#  'сергей': 0.07322886297376094,
#  'малое': 0.12123673469387755,
#  'облагаться': 0.06594761904761903,
#  'пеня': 0.04564761904761905,
#  '«известиям»': 0.09785714285714286,
#  'среднее': 0.10949795918367349,
#  'госуслуга': 0.07688163265306122,
#  '10': 0.054595578231292526,
#  'мошенник': 0.08742040816326531,
#  'мораторий': 0.04583673469387755,
#  'днр': 0.07528163265306123,
#  'тк': 0.12244897959183673,
#  'приостановка': 0.1089469387755102,
#  'максим': 0.06753061224489795,
#  'александр': 0.09046122448979592,
#  '17': 0.06820816326530611,
#  '12': 0.06520964749536177,
#  'военкомат': 0.09043413729128014,
#  'платёжный': 0.04426419294990724,
#  '10%': 0.04080816326530612,
#  'лнр': 0.07191428571428571,
#  'аккредитация': 0.09217052154195012,
#  'казахстан': 0.05281795918367347,
#  'усн': 0.21571644803229062,
#  'лимит': 0.05882979591836735,
#  '16': 0.03884489795918367,
#  'трлн': 0.03352380952380952,
#  '0%': 0.03392489795918367,
#  'риа': 0.05371020408163265,
#  'вс': 0.061763265306122445,
#  'аккредитовать': 0.09528798185941044,
#  'пфр': 0.0933265306122449,
#  'профильный': 0.08108673469387755,
#  'бухучёт': 0.06733333333333334,
#  'маркетплейс': 0.0536281179138322,
#  '20%': 0.03693877551020408,
#  'иа': 0.03998775510204082,
#  'херсонский': 0.07344081632653061,
#  'запорожский': 0.07344081632653061,
#  'фсс': 0.1982386936978259,
#  'набиуллин': 0.04729795918367348,
#  'ккт': 0.049833236151603504,
#  '13': 0.05448163265306123,
#  'роструд': 0.038318367346938775,
#  'субсидия': 0.030375510204081635,
#  'центробанк': 0.029118367346938775,
#  'аудиторский': 0.031717784256559765,
#  'недружественный': 0.023938775510204083,
#  'рбк': 0.024473469387755103,
#  'regnum': 0.022510204081632658,
#  '21': 0.05790612244897959,
#  '27': 0.05360408163265305,
#  '100': 0.08163265306122448,
#  'турция': 0.027061224489795917,
#  'пресс-служба': 0.02681224489795918,
#  '22': 0.06700874635568513,
#  'эльвира': 0.04334285714285714,
#  '11': 0.034826822157434406,
#  'минпромторг': 0.031167346938775504,
#  'юань': 0.03426530612244898,
#  'чм': 0.03688571428571428,
#  'юрлицо': 0.02230204081632653,
#  'мосбиржа': 0.08163265306122448,
#  'вице-премьер': 0.019473469387755103,
#  'повыситься': 0.025355102040816323,
#  'it': 0.07142857142857142,
#  'контрактник': 0.07142857142857142,
#  '300': 0.07142857142857142,
#  'оквэда': 0.17450233923493258,
#  'бронь': 0.05961428571428571,
#  'банкомат': 0.07142857142857142,
#  'минобороны': 0.06722448979591836,
#  'фсб': 0.10771947527749748,
#  'кадровик': 0.09600036693881295,
#  'прожиточный': 0.044009523809523804,
#  'бренд': 0.03103673469387755,
#  'замглавы': 0.021783673469387754,
#  '2024': 0.030551020408163265,
#  'роскомнадзор': 0.03369387755102041,
#  'кадастровый': 0.041125714285714286,
#  'антон': 0.021526530612244896,
#  'белоруссия': 0.015551020408163266,
#  'эмитент': 0.06124438124942665,
#  'решетник': 0.013506122448979592,
#  'кабмин': 0.041804081632653055,
#  'андрей': 0.019142857142857142,
#  'ефс-1': 0.061224489795918366,
#  'сзв-тд': 0.061224489795918366,
#  'приостанавливаться': 0.05578367346938776,
#  'критически': 0.03486530612244898,
#  'соответствующий': 0.02039591836734694,
#  'рассылка': 0.05557142857142857,
#  '2025': 0.029081632653061223,
#  'проиндексировать': 0.025122448979591837,
#  'ифнс': 0.031983673469387755,
#  'ozon': 0.03372244897959183,
#  'wildberries': 0.04384081632653061,
#  'псн': 0.10407302082377763,
#  'нпд': 0.08109347766259976,
#  'ужесточить': 0.031204081632653063,
#  'приостановление': 0.02,
#  'крым': 0.02284408163265306,
#  'сверка': 0.026979591836734696,
#  'по-прежнему': 0.035457142857142854,
#  '400': 0.019575510204081634,
#  'депозит': 0.12134207870837538,
#  '28': 0.01626938775510204,
#  'сбербанк': 0.01648979591836735,
#  'минсельхоз': 0.01729795918367347,
#  'облагать': 0.01740816326530612,
#  'конвертация': 0.0353637280983396,
#  'скорее': 0.021281632653061225,
#  'мсп': 0.02070612244897959,
#  'сазан': 0.035861224489795916,
#  'брокер': 0.013277551020408162,
#  'аусна': 0.014272653061224489,
#  'еаэс': 0.01733877551020408,
#  '23': 0.0526204081632653,
#  'зампред': 0.01883265306122449,
#  'пф': 0.03146938775510204,
#  '60': 0.05102040816326531,
#  'сво': 0.425531914893617,
#  'увольнять': 0.05102040816326531,
#  'тд': 0.05102040816326531,
#  'бухгалтерия': 0.027804081632653063,
#  '30%': 0.04520408163265306,
#  'возобновление': 0.03196734693877551,
#  'заблокировать': 0.028404081632653063,
#  'главбух': 0.03548163265306122,
#  'кто-то': 0.02607482993197279,
#  'володин': 0.02451836734693878,
#  'санкционный': 0.015722448979591838,
#  '75%': 0.03316326530612245,
#  '6%': 0.03266122448979592,
#  'нетрудоспособность': 0.01842857142857143,
#  'аванс': 0.06513163929914687,
#  'избежание': 0.020918367346938773,
#  'минтранс': 0.016846938775510203,
#  'ооо': 0.020903061224489795,
#  'ст': 0.01633061224489796,
#  'злоумышленник': 0.019175510204081633,
#  'арендный': 0.013744897959183672,
#  'акциз': 0.04382625447206678,
#  'застройщик': 0.012685714285714286,
#  '14': 0.018134693877551022,
#  'нерезидент': 0.04105127969911017,
#  'основное': 0.011391836734693878,
#  'малоимущий': 0.03804591836734694,
#  'ндпить': 0.009959183673469388,
#  '20': 0.016020408163265307,
#  'моисеев': 0.013257142857142858,
#  'намерить': 0.011718367346938777,
#  'игорь': 0.020420408163265305,
#  'дмитрий': 0.049102040816326534,
#  'евросоюз': 0.008400000000000001,
#  'пресс-секретарь': 0.04081632653061224,
#  'подлежащее': 0.03649795918367347,
#  '50%': 0.03461632653061224,
#  'анонсировать': 0.04081632653061224,
#  'призывный': 0.0264,
#  'вячеслав': 0.030506122448979586,
#  '26': 0.028216326530612245,
#  '1с': 0.034848979591836735,
#  'приостанавливать': 0.03284081632653061,
#  'маркировка': 0.024914285714285715,
#  'санкт-петербург': 0.03236734693877551,
#  'фас': 0.01873877551020408,
#  'беременная': 0.04059591836734694,
#  'корректировка': 0.02533469387755102,
#  '15%': 0.03356734693877551,
#  'гибдд': 0.023497959183673468,
#  '55': 0.02944489795918367,
#  'беларусь': 0.02730612244897959,
#  'осаго': 0.02177142857142857,
#  'автовладелец': 0.02444489795918367,
#  'банкрот': 0.021053061224489796,
#  '200': 0.015114285714285714,
#  'плательщик': 0.02446938775510204,
#  'латвия': 0.020053061224489795,
#  'счёт-фактура': 0.022236734693877547,
#  'дивиденд': 0.04725866128489741,
#  'вакансия': 0.0195469387755102,
#  'мошеннический': 0.016375510204081633,
#  'учётный': 0.024191836734693876,
#  '1%': 0.018714285714285715,
#  'массово': 0.013061224489795917,
#  '25': 0.01953877551020408,
#  'ос': 0.02371836734693877,
#  'начисление': 0.022028571428571425,
#  'мрот': 0.04477800201816347,
#  '2019': 0.014791836734693876,
#  'отчитываться': 0.018020408163265306,
#  'фтс': 0.018514285714285712,
#  'упд': 0.058779011099899095,
#  'минприрода': 0.012416326530612245,
#  'россии»': 0.018285714285714284,
#  'софт': 0.015959183673469386,
#  'индексация': 0.013661224489795917,
#  'росстат': 0.044170259609210165,
#  'евгений': 0.027767346938775507,
#  'сбер': 0.01576326530612245,
#  'онлайн': 0.012514285714285712,
#  'армения': 0.014224489795918366,
#  'документооборот': 0.03093752866709476,
#  '70': 0.02146938775510204,
#  'бухотчётность': 0.013922448979591837,
#  'жкх': 0.008746938775510202,
#  'беспошлинный': 0.013604081632653059,
#  'ввоз': 0.037481632653061224,
#  'аудит': 0.0280249518392808,
#  'наслать': 0.013326530612244897,
#  'социально-экономический': 0.011914285714285712,
#  'полис': 0.014632653061224488,
#  'рекордный': 0.015587755102040815,
#  'неквалифицированный': 0.007885714285714286,
#  'мвд': 0.009365986394557822,
#  'микрозаём': 0.007097959183673469,
#  '2023-2025': 0.009012244897959184,
#  'списывать': 0.016391836734693875,
#  'антимонопольный': 0.013251700680272108,
#  'telegram-канал': 0.014746938775510204,
#  'ук': 0.02406530612244898,
#  '«альфа-капитал»': 0.02406530612244898,
#  'тасс': 0.03197551020408163,
#  '«известий»': 0.011579591836734694,
#  '&gt;&gt;&gt;': 0.030877551020408157,
#  'лдпр': 0.01480408163265306,
#  'высокооплачиваемый': 0.011733333333333332,
#  'иван': 0.01229795918367347,
#  '"коммерсант"': 0.00610204081632653,
#  '50': 0.030612244897959183,
#  '65': 0.030612244897959183,
#  '195': 0.030612244897959183,
#  'призывник': 0.030612244897959183,
#  'начислить': 0.030612244897959183,
#  'грамотность': 0.017746938775510205,
#  '3517': 0.023416326530612246,
#  'стимулирование': 0.02219591836734694,
#  '182н': 0.030612244897959183,
#  'белгородский': 0.021893877551020405,
#  '(работа': 0.019685714285714286,
#  'контрагент': 0.055361893404274824,
#  'годность': 0.025314285714285716,
#  'анатолий': 0.02043673469387755,
#  'аксаков': 0.02043673469387755,
#  'начислять': 0.030612244897959183,
#  '70%': 0.017244897959183672,
#  '5%': 0.020493877551020407,
#  'потенциально': 0.030612244897959183,
#  '2026': 0.011191836734693877,
#  'максут': 0.030612244897959183,
#  'шадаев': 0.030612244897959183,
#  'получатель': 0.015902040816326533,
#  'it-специалист': 0.01739591836734694,
#  '46': 0.024151020408163262,
#  'экипировка': 0.01726122448979592,
#  '2014': 0.023322448979591837,
#  'всё-таки': 0.01780408163265306,
#  'распечатать': 0.026571428571428572,
#  'windows': 0.009955102040816326,
#  '2015': 0.030612244897959183,
#  '100%': 0.019583673469387754,
#  'прогул': 0.015183673469387754,
#  '(до': 0.02346938775510204,
#  '24': 0.02204489795918367,
#  'занятой': 0.018828571428571427,
#  'нотариальный': 0.030612244897959183,
#  'гпх': 0.07826116870011925,
#  'размещать': 0.011755102040816326,
#  'соцсеть': 0.013269387755102042,
#  'реквизит': 0.05499495459132189,
#  'альфа-банк': 0.017016326530612247,
#  'ольга': 0.009057142857142857,
#  'оформляться': 0.010595918367346939,
#  'мобилизационный': 0.018297959183673468,
#  'аннулировать': 0.021359183673469388,
#  '000': 0.019293877551020407,
#  'поменяться': 0.024273469387755098,
#  'недобросовестный': 0.014012244897959183,
#  'кассовый': 0.021946938775510204,
#  'взимание': 0.009959183673469388,
#  'оспорить': 0.018281632653061222,
#  'травматизм': 0.017293877551020406,
#  'мойка': 0.008693877551020407,
#  'грузия': 0.01136734693877551,
#  'подорожать': 0.014542857142857144,
#  'программно-аппаратный': 0.013775510204081633,
#  'фискальный': 0.010563265306122447,
#  'неработающий': 0.013016326530612245,
#  'безотзывный': 0.013355102040816327,
#  'списание': 0.010928571428571428,
#  '500': 0.011187755102040816,
#  '«единый': 0.014812244897959185,
#  'послабление': 0.024673469387755102,
#  'ес': 0.01540408163265306,
#  '«клерке»': 0.014379591836734693,
#  'toyota': 0.010240816326530613,
#  '149': 0.012277551020408162,
#  'выкупить': 0.010828571428571429,
#  'apple': 0.011865306122448979,
#  'ретейлер': 0.012289795918367347,
#  '2%': 0.01306530612244898,
#  'мсфо': 0.010297959183673468,
#  '(ifrs)': 0.010297959183673468,
#  'ежемесячный': 0.007469387755102041,
#  'узбекистан': 0.01123265306122449,
#  '8%': 0.015183673469387754,
#  '2020': 0.0103265306122449,
#  'тестировать': 0.009836734693877552,
#  'выемка': 0.011897959183673468,
#  'дистанционный': 0.008253061224489796,
#  'безналичный': 0.01446938775510204,
#  'доначисление': 0.013755102040816326,
#  'разморозка': 0.009459183673469387,
#  'криптовалюта': 0.008322448979591836,
#  'субсидировать': 0.008330612244897959,
#  'айтишник': 0.010314285714285715,
#  'евразийский': 0.01116734693877551,
#  'трата': 0.015840816326530616,
#  '22%': 0.010346938775510205,
#  'заём': 0.008522448979591837,
#  'системообразующий': 0.009604081632653062,
#  'мспрф': 0.00933469387755102,
#  'безработный': 0.014151020408163266,
#  'уволиться': 0.01203265306122449,
#  'истекать': 0.007918367346938775,
#  'прорабатывать': 0.008424489795918368,
#  'уведомить': 0.010138775510204081,
#  'рейтинговый': 0.009191836734693875,
#  'спрогнозировать': 0.013032653061224489,
#  'драгметалл': 0.006359183673469388,
#  'ребрендинг': 0.006865306122448979,
#  'втб': 0.006824489795918367,
#  '17%': 0.00930204081632653,
#  '40': 0.017236734693877553,
#  'расписка': 0.005208163265306123,
#  'госрегистрация': 0.005579591836734695,
#  'авто': 0.007395918367346939,
#  '1500': 0.0040122448979591835,
#  'миронов': 0.011257142857142858,
#  'ввп': 0.00633061224489796,
#  'страхователь': 0.004436734693877551,
#  'sputnik': 0.009387755102040816,
#  'резидент': 0.03413677644252821,
#  'промышленник': 0.011612244897959183,
#  'пленарный': 0.01445714285714286,
#  'минэкономики': 0.004506122448979592,
#  '«вечерня': 0.030612244897959183,
#  'исчислить': 0.006171428571428572,
#  'б/с': 0.003955102040816327,
#  'superjob': 0.02451428571428571,
#  'rt': 0.010155102040816325,
#  'еврокомиссия': 0.005583673469387755,
#  'новостройка': 0.02100612244897959,
#  '"каникулы"': 0.008930612244897959,
#  'импортозамещение': 0.0186772952276982,
#  'незаконно': 0.011453061224489797,
#  'инна': 0.037358957893771215,
#  'белоус': 0.005240816326530612,
#  '"о': 0.01633469387755102,
#  'макроэкономический': 0.013616326530612243,
#  'краткосрочный': 0.017285714285714286,
#  'мид': 0.02040816326530612,
#  'обнародовать': 0.02040816326530612,
#  '712': 0.02040816326530612,
#  '«сведение': 0.02040816326530612,
#  'персучёт': 0.02040816326530612,
#  'производстве»': 0.02040816326530612,
#  'вели': 0.02040816326530612,
#  'очный': 0.02040816326530612,
#  'очно-заочный': 0.02040816326530612,
#  'упрощать': 0.02040816326530612,
#  'повторно': 0.02040816326530612,
#  'кбк': 0.09090909090909091,
#  '102': 0.019812244897959182,
#  'ростуризм': 0.018146938775510203,
#  'гособоронзаказ': 0.02040816326530612,
#  'неявка': 0.02040816326530612,
#  'оставление': 0.02040816326530612,
#  'услуг)': 0.016518367346938775,
#  'росстандарт': 0.02040816326530612,
#  'фитнес-клуб': 0.016983673469387756,
#  '«у': 0.018061224489795916,
#  'спецоценка': 0.017330612244897958,
#  'нанимать': 0.018661224489795916,
#  'ратификация': 0.009355102040816325,
#  'медиа': 0.02040816326530612,
#  'туроператор': 0.009020408163265305,
#  'майнинга': 0.010644897959183672,
#  'договорный': 0.017457142857142855,
#  'прослеживаемость': 0.02040816326530612,
#  'штрафовать': 0.02040816326530612,
#  'запросить': 0.009261224489795918,
#  '$400': 0.005420408163265306,
#  'инвестировать': 0.016359183673469387,
#  'нпф': 0.02040816326530612,
#  'иванович': 0.02040816326530612,
#  'ikea': 0.02040816326530612,
#  'осный': 0.015653061224489794,
#  'капремонт': 0.02040816326530612,
#  'фссп': 0.009330612244897958,
#  'водительский': 0.013583673469387754,
#  'роды': 0.013987755102040816,
#  'пересчитывать': 0.015742857142857142,
#  '188': 0.017987755102040814,
#  '250': 0.01964081632653061,
#  'снилс': 0.018457142857142856,
#  'приёмка': 0.0195469387755102,
#  'шенгенский': 0.011473469387755102,
#  'матвиенко': 0.01599591836734694,
#  'нецелесообразный': 0.017379591836734692,
#  '1/3': 0.017069387755102042,
#  'даниил': 0.009922448979591837,
#  'егоров': 0.009922448979591837,
#  'проактивный': 0.01396326530612245,
#  '«этый': 0.01306938775510204,
#  'рассылать': 0.019477551020408164,
#  'подраздел': 0.018922448979591836,
#  '41%': 0.005657142857142857,
#  'довольствие': 0.02040816326530612,
#  '(переть': 0.011763265306122449,
#  'пристав': 0.01183265306122449,
#  'дорогой': 0.01400408163265306,
#  'вредить': 0.009820408163265305,
#  'прослеживать': 0.014763265306122448,
#  'баталин': 0.0073346938775510195,
#  'озвучить': 0.006889795918367346,
#  'топ': 0.014371428571428571,
#  'ростов-на-дону': 0.013620408163265305,
#  'продлевать': 0.009816326530612244,
#  'накопительный': 0.012167346938775508,
#  'adidas': 0.01237142857142857,
#  'неуплата': 0.012277551020408162,
#  'тимбилдинг': 0.013248979591836733,
#  'тульский': 0.010799999999999999,
#  'возмещать': 0.00923265306122449,
#  '(сфр)': 0.020065306122448976,
#  'ежемесячно': 0.01274285714285714,
#  'штрихкод': 0.01177142857142857,
#  'bank': 0.012685714285714286,
#  'гарантийный': 0.013420408163265304,
#  'ввозить': 0.007530612244897959,
#  '«на': 0.007481632653061223,
#  'профзаболевание': 0.012608163265306121,
#  'разовый': 0.010555102040816326,
#  '26%': 0.010081632653061223,
#  'поддельный': 0.02034285714285714,
#  'несвоевременный': 0.02040816326530612,
#  'загранпаспорт': 0.008677551020408163,
#  'комплектующие': 0.006726530612244898,
#  '(противодействия)': 0.01920816326530612,
#  'ратифицировать': 0.004387755102040816,
#  'пилотный': 0.010057142857142857,
#  'банкинг': 0.010595918367346939,
#  '864': 0.00853877551020408,
#  'гоз': 0.011134693877551019,
#  'гис': 0.007404081632653061,
#  'графа': 0.015616326530612243,
#  '135': 0.005338775510204081,
#  'спецоперация': 0.009632653061224489,
#  'легализовать': 0.0076326530612244895,
#  'въезжать': 0.012159183673469387,
#  'трудоустройство': 0.008791836734693878,
#  'кризисный': 0.012040816326530611,
#  'общепит': 0.008391836734693877,
#  '350': 0.012122448979591836,
#  'суточный': 0.009922448979591837,
#  'партнёрский': 0.011289795918367346,
#  'активизироваться': 0.017289795918367344,
#  'визовый': 0.00957142857142857,
#  'выгодоприобретатель': 0.04274327787403202,
#  'санаторно-курортный': 0.010612244897959183,
#  'п9': 0.008122448979591837,
#  'собянин': 0.011081632653061224,
#  'окз': 0.009726530612244898,
#  'черногория': 0.0076326530612244895,
#  '6/2020': 0.009093877551020407,
#  'автоконцерн': 0.00803265306122449,
#  '05': 0.011195918367346937,
#  'пп': 0.007885714285714286,
#  'it-бизнес': 0.009061224489795917,
#  'стартап': 0.03623848691237803,
#  'пбу': 0.018507476378313917,
#  'шойгу': 0.01277142857142857,
#  'допуск': 0.006685714285714285,
#  'вечером': 0.008175510204081632,
#  'мессенджер': 0.00770204081632653,
#  '25/2018': 0.01089795918367347,
#  'ппа': 0.008877551020408162,
#  '«об': 0.007799999999999999,
#  '76%': 0.008163265306122448,
#  'тратиться': 0.007710204081632653,
#  'карточный': 0.02040816326530612,
#  'revolut': 0.009469387755102041,
#  'подключиться': 0.008448979591836733,
#  'продление': 0.006187755102040816,
#  '(иис)': 0.005889795918367347,
#  'возгорание': 0.007791836734693876,
#  'рсв': 0.01743673469387755,
#  'дебетовый': 0.008440816326530612,
#  'кешбэк': 0.0069551020408163255,
#  'поблажка': 0.007583673469387754,
#  'адвокатский': 0.008159183673469387,
#  'учете»': 0.009024489795918366,
#  'совершенствовать': 0.009493877551020408,
#  'сбп': 0.019631226492982295,
#  'зачислить': 0.006089795918367347,
#  '«кнопка»': 0.009306122448979591,
#  'смартфон': 0.007946938775510204,
#  'предупредительный': 0.00583673469387755,
#  '46%': 0.006248979591836735,
#  'предзаказ': 0.007616326530612244,
#  '990': 0.007616326530612244,
#  '60%': 0.006832653061224489,
#  'непристегнуть': 0.009126530612244896,
#  'внереализационный': 0.00843673469387755,
#  'partners': 0.0066489795918367334,
#  'fix': 0.006697959183673469,
#  'price': 0.006697959183673469,
#  '52': 0.006665306122448979,
#  'росреестр': 0.004518367346938775,
#  'вредоносный': 0.006032653061224489,
#  '859%': 0.006493877551020408,
#  'выездной': 0.006493877551020408,
#  'мфц': 0.006244897959183673,
#  'силуановый': 0.006310204081632652,
#  'провайдер': 0.0049387755102040815,
#  'онлайн-школа': 0.007310204081632653,
#  'графика': 0.011620408163265306,
#  'гир': 0.006624489795918367,
#  'бо': 0.006624489795918367,
#  'товаропроизводитель': 0.005232653061224489,
#  '€1000': 0.006591836734693877,
#  'хозпостройка': 0.008106122448979592,
#  '(центробанк': 0.007053061224489796,
#  'цб)': 0.007053061224489796,
#  '«двигать»': 0.007053061224489796,
#  '4%': 0.004648979591836734,
#  '«клеркпремиум»': 0.005881632653061224,
#  '29': 0.008518367346938775,
#  'финляндия': 0.006191836734693877,
#  '9%': 0.005473469387755101,
#  'нк)': 0.006408163265306122,
#  'аутсорсинг': 0.006473469387755101,
#  '«клерк»': 0.00703265306122449,
#  '124%': 0.00536734693877551,
#  'предпенсионер': 0.006138775510204081,
#  '2018': 0.006314285714285714,
#  'appstore': 0.006142857142857142,
#  'киргизия': 0.006987755102040815,
#  'нежилой': 0.00620408163265306,
#  'неограниченный': 0.005432653061224489,
#  '3%': 0.0068081632653061224,
#  'удалённый': 0.005914285714285714,
#  'экстренный': 0.018722448979591834,
#  'реорганизовать': 0.005416326530612245,
#  'лизинговый': 0.004159183673469387,
#  'товарооборот': 0.005999999999999999,
#  'приравниваться': 0.006187755102040816,
#  'благотворительность': 0.004820408163265306,
#  '1000': 0.008089795918367346,
#  'рецептурный': 0.004514285714285714,
#  'топ-15': 0.005971428571428571,
#  'просрочить': 0.005685714285714285,
#  'вина': 0.004126530612244898,
#  'запчасть': 0.004648979591836734,
#  'ндд': 0.004122448979591836,
#  'импортёр': 0.009345472892395193,
#  'vk': 0.0056408163265306115,
#  'club': 0.006351020408163264,
#  'фз': 0.004812244897959184,
#  'татарстан': 0.0058,
#  'поощрение': 0.003922448979591837,
#  'капиталовложение': 0.003922448979591837,
#  'дилерский': 0.004310204081632653,
#  'подмосковье': 0.005587755102040816,
#  'депозитарий': 0.02040816326530612,
#  'наравне': 0.004306122448979591,
#  'госкомпания': 0.005020408163265305,
#  'денис': 0.0043918367346938774,
#  'мантур': 0.0043918367346938774,
#  '(от': 0.004371428571428571,
#  'госзакупка': 0.0048734693877551015,
#  '65%': 0.004999999999999999,
#  '56': 0.012975510204081633,
#  'mazda': 0.004853061224489795,
#  'просрочка': 0.004408163265306122,
#  'коронавирус': 0.0038734693877551015,
#  'mazars': 0.005424489795918366,
#  'слиток': 0.004583673469387754,
#  'проинформировать': 0.003208163265306122,
#  'отзывный': 0.003208163265306122,
#  'qiwi': 0.004506122448979592,
#  '32%': 0.004869387755102041,
#  '557': 0.004795918367346938,
#  'восстанавливаться': 0.004893877551020408,
#  'иис': 0.004840816326530612,
#  'unionpay': 0.004142857142857143,
#  '05%': 0.004163265306122449,
#  '24%': 0.0036653061224489795,
#  'некоммерческий': 0.003930612244897959,
#  'перераспределить': 0.0032367346938775507,
#  'экспортёр': 0.006608163265306121,
#  'испытательный': 0.0069551020408163255,
#  'зарегистрироваться': 0.006285714285714285,
#  'москвы»': 0.009975510204081632,
#  'рублёвый': 0.02040816326530612,
#  'депозитарный': 0.0031224489795918364,
#  'замедлиться': 0.0028816326530612243,
#  '(на': 0.009134693877551019,
#  'ужесточение': 0.02040816326530612,
#  'базисный': 0.013546938775510203,
#  'джиоев': 0.010061224489795918,
#  'аналитика': 0.02040816326530612,
#  '134': 0.003922448979591837,
#  '«интерфакс»': 0.005832653061224489,
#  'срзп': 0.007248979591836734,
#  '23%': 0.0046326530612244895,
#  '"согласие"': 0.02040816326530612,
#  'баррель': 0.009812244897959182,
#  'инвестирование': 0.012914285714285713,
#  'мск': 0.0044571428571428574,
#  '«деловой': 0.004510204081632652,
#  'коррекция': 0.02040816326530612,
#  'неприменение': 0.00924081632653061,
#  'жилищно-коммунальный': 0.009559183673469387,
#  'скупка': 0.004889795918367346,
#  'упростить': 0.007265306122448979,
#  '«этажи»': 0.016302040816326527,
#  '(вэф)': 0.004314285714285714,
#  'ernst': 0.005183673469387755,
#  '&amp;': 0.005183673469387755,
#  'young': 0.005183673469387755,
#  '2030': 0.0024653061224489793,
#  'предусмотренный': 0.006702040816326531,
#  'пропорционально': 0.009330612244897958,
#  'зампредседателя': 0.02040816326530612,
#  'совфеда': 0.014751020408163264,
#  'тренд': 0.005122448979591836,
#  'краснов': 0.0034408163265306118,
#  'bloomberg': 0.009840816326530612,
#  'москвой»': 0.02040816326530612,
#  'перерасчёт': 0.02040816326530612,
#  'пассив': 0.018351020408163263,
#  'взыскать': 0.003489795918367347,
#  'недоимка': 0.003489795918367347,
#  'леонид': 0.003755102040816326,
#  'горнина': 0.003755102040816326,
#  '«работару»': 0.0073346938775510195,
#  'вразрез': 0.012595918367346937,
#  'выманивание': 0.0046693877551020405,
#  'инфляционный': 0.006848979591836734,
#  '"прайм"': 0.006616326530612244,
#  '19': 0.005040816326530612,
#  'карантин': 0.012065306122448978,
#  'денежно-кредитный': 0.012440816326530612,
#  'опек': 0.002636734693877551,
#  'взаимозачёт': 0.0036163265306122447,
#  '2023–2025': 0.006061224489795918,
#  'стойкость': 0.02040816326530612,
#  'чебесков': 0.0030326530612244896,
#  'аудиторов»': 0.008016326530612244,
#  'zoom': 0.005293877551020408,
#  '(мск)': 0.005959183673469387,
#  'оговорить': 0.02034285714285714,
#  'трёхлетний': 0.003257142857142857,
#  'стратег': 0.02040816326530612,
#  'бахтин': 0.02040816326530612,
#  '19%': 0.003808163265306122,
#  '“ъ”': 0.003420408163265306,
#  '«известия»': 0.020163265306122446,
#  'наталья': 0.002877551020408163,
#  'дольщик': 0.0031428571428571426,
#  'антироссийский': 0.005240816326530611,
#  'законодательно': 0.0027959183673469386,
#  'новшество': 0.0036448979591836733,
#  'замруководитель': 0.0026448979591836732,
#  'артём': 0.007306122448979591,
#  'потребкредит': 0.0030163265306122444,
#  'фиксация': 0.017734693877551017,
#  'ру»': 0.01450204081632653,
#  '2016': 0.0037673469387755096,
#  'нина': 0.004146938775510204,
#  'останин': 0.004146938775510204,
#  'донбасс': 0.00413469387755102,
#  'владислав': 0.008742857142857142,
#  'суверенный': 0.004608163265306122,
#  'корректировать': 0.002759183673469387,
#  'ускоренный': 0.011122448979591837,
#  'нацвалюта': 0.004261224489795918,
#  '(цмакп)': 0.009077551020408163,
#  'россии"': 0.0028693877551020405,
#  '22h2': 0.0037591836734693876,
#  'перечисление': 0.005379591836734693,
#  'смягчить': 0.02040816326530612,
#  'ек': 0.0035673469387755103,
#  'заботкин': 0.02040816326530612,
#  'укрепиться': 0.00533469387755102,
#  '32': 0.006657142857142856,
#  'клиринговый': 0.02040816326530612,
#  '(нкц)': 0.02040816326530612,
#  'нкц': 0.02040816326530612,
#  'сро': 0.008783597835061004,
#  'аас': 0.0031265306122448978,
#  'валерий': 0.006595918367346938,
#  '"госуслуги"': 0.006832653061224489,
#  'рубля)': 0.02040816326530612,
#  'головченко': 0.002338775510204081,
#  'коксоваться': 0.001914285714285714,
#  '2514': 0.003763265306122449,
#  'срочник': 0.01020408163265306,
#  'сержантский': 0.01020408163265306,
#  'австрия': 0.01020408163265306,
#  '2609': 0.01020408163265306,
#  'гигиена': 0.01020408163265306,
#  'соцстрахование': 0.01020408163265306,
#  'надбавка': 0.01020408163265306,
#  'георгиевский': 0.01020408163265306,
#  'высококвалифицированный': 0.01020408163265306,
#  'неправомерно': 0.01020408163265306,
#  '№7': 0.01020408163265306,
#  '10-11': 0.006959183673469388,
#  'обществознание': 0.006959183673469388,
#  'спальная': 0.01020408163265306,
#  'термобельё': 0.01020408163265306,
#  '10-20%': 0.01020408163265306,
#  'платёжка': 0.01020408163265306,
#  'октмый': 0.01020408163265306,
#  '«налоговый': 0.01020408163265306,
#  'тайна»': 0.01020408163265306,
#  'интригующий': 0.009342857142857142,
#  'клерк': 0.009342857142857142,
#  'мерч': 0.009342857142857142,
#  'толстовка': 0.009342857142857142,
#  'принтом': 0.009342857142857142,
#  'стиль!': 0.009342857142857142,
#  'гладков': 0.01020408163265306,
#  'заговаривать': 0.01020408163265306,
#  'ужесточать': 0.01020408163265306,
#  'самовольный': 0.01020408163265306,
#  'дезертирство': 0.01020408163265306,
#  'счетно-сортировальный': 0.01020408163265306,
#  'валидатор': 0.01020408163265306,
#  '115-фз': 0.01020408163265306,
#  'него?': 0.01020408163265306,
#  'отчетностью?': 0.01020408163265306,
#  '«новое': 0.01020408163265306,
#  'люди»': 0.01020408163265306,
#  'решетников': 0.01020408163265306,
#  'скан': 0.01020408163265306,
#  'разбогатеть': 0.00889795918367347,
#  'iт-компания': 0.01020408163265306,
#  'привлекаться': 0.01020408163265306,
#  'брифинг': 0.01020408163265306,
#  'специальности»': 0.01020408163265306,
#  '40-50%': 0.006779591836734693,
#  'медучреждение': 0.01020408163265306,
#  'говорящий': 0.01020408163265306,
#  'квд': 0.01020408163265306,
#  'радикулит': 0.01020408163265306,
#  'сзв-стаж': 0.01020408163265306,
#  'безвизовый': 0.01020408163265306,
#  'сторонний': 0.01020408163265306,
#  'кудрин': 0.01020408163265306,
#  '«яндекс»': 0.01020408163265306,
#  'увозить': 0.01020408163265306,
#  '«кадровый': 0.01020408163265306,
#  'дырами»': 0.01020408163265306,
#  'работник-мужчина': 0.01020408163265306,
#  '«эвакуировали»': 0.01020408163265306,
#  'iт': 0.01020408163265306,
#  '(атор)': 0.0054571428571428575,
#  '205': 0.01020408163265306,
#  'якутия': 0.01020408163265306,
#  'авдонин': 0.01020408163265306,
#  'авиабилет': 0.00783673469387755,
#  'хождение': 0.008118367346938774,
#  '44-фз': 0.01020408163265306,
#  '25-го': 0.01020408163265306,
#  '28-быть': 0.01020408163265306,
#  'студент-очник': 0.01020408163265306,
#  'магистратура': 0.01020408163265306,
#  'заочный': 0.01020408163265306,
#  '$100': 0.004191836734693877,
#  '«бумажный': 0.01020408163265306,
#  'привычки»': 0.01020408163265306,
#  'файл': 0.01020408163265306,
#  'невыход': 0.007795918367346938,
#  'образцово': 0.005999999999999999,
#  'раскритиковать': 0.007583673469387754,
#  'иванов': 0.01020408163265306,
#  'анна': 0.01020408163265306,
#  'абрамович': 0.01020408163265306,
#  'изольда': 0.01020408163265306,
#  'призадуматься': 0.01020408163265306,
#  'mcdonald’s': 0.008546938775510203,
#  '3-ндфл': 0.01020408163265306,
#  '13%': 0.01020408163265306,
#  'разворачивать': 0.01020408163265306,
#  'репатриация': 0.01020408163265306,
#  'великобритания': 0.0057061224489795915,
#  'microsoft': 0.0061959183673469375,
#  'раскусить': 0.01020408163265306,
#  'разыграть': 0.01020408163265306,
#  'микроэлектроника': 0.0075673469387755096,
#  'нуждаемость': 0.01020408163265306,
#  'маркетплейс?': 0.01020408163265306,
#  '15%)': 0.01020408163265306,
#  'лесопромышленный': 0.01020408163265306,
#  'переориентация': 0.01020408163265306,
#  'спч': 0.01020408163265306,
#  'точен': 0.01020408163265306,
#  'взыскивать': 0.008946938775510204,
#  'внесудебный': 0.008946938775510204,
#  'летательный': 0.01020408163265306,
#  'дтп': 0.01020408163265306,
#  '6038-у': 0.01020408163265306,
#  'нововведение': 0.01010204081632653,
#  'прибалтийский': 0.006220408163265306,
#  'mango': 0.01020408163265306,
#  'zara': 0.01020408163265306,
#  'коворкинг': 0.008257142857142857,
#  'золотовалютный': 0.004897959183673469,
#  'бережливый': 0.008506122448979591,
#  'финорганизация': 0.01020408163265306,
#  'бизнес-омбудсмен': 0.006302040816326531,
#  '«забизнесрф»': 0.006302040816326531,
#  'элина': 0.006302040816326531,
#  'сидоренко': 0.006302040816326531,
#  '136': 0.0059469387755102035,
#  'полмесяца': 0.0059469387755102035,
#  '(без': 0.004375510204081633,
#  'заявлений)': 0.004375510204081633,
#  'подмога': 0.009808163265306123,
#  'напрягаться': 0.009808163265306123,
#  'зачем?': 0.009808163265306123,
#  'хотите?»': 0.009808163265306123,
#  'неполученный': 0.01020408163265306,
#  'отчитывать': 0.01020408163265306,
#  '(ить': 0.009061224489795917,
#  'закона)': 0.009061224489795917,
#  '(рсв': 0.007065306122448979,
#  '6-ндфл)': 0.007065306122448979,
#  'ип-работодатель': 0.007065306122448979,
#  'егрюла': 0.01020408163265306,
#  'егрипа': 0.01020408163265306,
#  'двухуровневый': 0.01016734693877551,
#  '«красный': 0.01020408163265306,
#  'белое»': 0.01020408163265306,
#  '«додый': 0.01020408163265306,
#  'пицца»': 0.01020408163265306,
#  'пицца': 0.01020408163265306,
#  'приём-увольнение': 0.01020408163265306,
#  'lada': 0.004175510204081632,
#  'алименты': 0.01020408163265306,
#  'удерживаться': 0.01020408163265306,
#  'авиасообщение': 0.006522448979591836,
#  'кипр': 0.006522448979591836,
#  'онлайн-касса': 0.035478396477387396,
#  'касательно': 0.01020408163265306,
#  'тёзка': 0.006097959183673469,
#  'отчества)': 0.006097959183673469,
#  'суперкомпьютер': 0.008444897959183673,
#  '«т-платформы»': 0.008444897959183673,
#  'подконтрольный': 0.009134693877551019,
#  'упрощенок': 0.009134693877551019,
#  'отгрузить': 0.009926530612244897,
#  'пресекать': 0.01020408163265306,
#  'фсбу?': 0.01020408163265306,
#  '«чрезмерный': 0.005653061224489796,
#  'здоровью!': 0.005653061224489796,
#  'враг!»': 0.005653061224489796,
#  '–31': 0.01020408163265306,
#  'донецкий': 0.008016326530612244,
#  'луганский': 0.008016326530612244,
#  'договорник': 0.008751020408163265,
#  'пароль': 0.007102040816326529,
#  '«газпрома»': 0.006710204081632652,
#  '5103': 0.006710204081632652,
#  '200-210': 0.009253061224489796,
#  'топ-5': 0.009253061224489796,
#  'заморозка': 0.007587755102040816,
#  '«госуслуг»': 0.009212244897959184,
#  '121': 0.01020408163265306,
#  'умерший': 0.00983265306122449,
#  'джерси': 0.0056244897959183675,
#  'гознак': 0.00396734693877551,
#  'полиграфия': 0.00396734693877551,
#  'банкнот': 0.00396734693877551,
#  'марка': 0.00396734693877551,
#  '010722': 0.009632653061224489,
#  '030723': 0.009632653061224489,
#  '14072022': 0.01020408163265306,
#  '№266-фз': 0.01020408163265306,
#  'тренинг': 0.006265306122448979,
#  'оксфордский': 0.006142857142857142,
#  'сверхумный': 0.006142857142857142,
#  'из-под': 0.006142857142857142,
#  'фатальный': 0.006142857142857142,
#  '442%': 0.007571428571428571,
#  'медианный': 0.007571428571428571,
#  'отпускной': 0.009183673469387754,
#  'гасить': 0.009995918367346939,
#  'госслужба': 0.006714285714285714,
#  '920': 0.01020408163265306,
#  'обновиться': 0.01020408163265306,
#  'kb': 0.004024489795918367,
#  'euronet': 0.004024489795918367,
#  'классификатор': 0.008579591836734693,
#  '01012022': 0.008579591836734693,
#  'мусоровоз': 0.008579591836734693,
#  'мошенничество': 0.006571428571428571,
#  'фейковый': 0.006571428571428571,
#  'интернет-площадка': 0.008081632653061225,
#  'креатив': 0.008081632653061225,
#  '«география»': 0.007375510204081632,
#  'курортный': 0.004881632653061224,
#  'кубань': 0.004881632653061224,
#  'ставрополье': 0.004881632653061224,
#  'алтайский': 0.004881632653061224,
#  'вовлечение': 0.008955102040816326,
#  'невостребованный': 0.008955102040816326,
#  'сельхозземеля': 0.008955102040816326,
#  'свериться': 0.008955102040816326,
#  'пальмовый': 0.00476734693877551,
#  'лазейка': 0.00476734693877551,
#  'дедушке»': 0.005551020408163266,
#  '«100': 0.005551020408163266,
#  'км': 0.005551020408163266,
#  'дороги»': 0.005551020408163266,
#  'обособленный': 0.005551020408163266,
#  'ос-09-3-1': 0.005551020408163266,
#  'фиас': 0.005551020408163266,
#  'ежеквартально': 0.009379591836734693,
#  '(оквэда': 0.0037959183673469386,
#  '45203)': 0.0037959183673469386,
#  '«технический': 0.0037959183673469386,
#  'автотранспортный': 0.0037959183673469386,
#  'средств»': 0.0037959183673469386,
#  'техобслуживание': 0.0037959183673469386,
#  'неофициально': 0.005399999999999999,
#  'raiffeisen': 0.008661224489795918,
#  '«дочки»': 0.008661224489795918,
#  'изымать': 0.006179591836734694,
#  'астана': 0.006179591836734694,
#  'поощрительный': 0.007644897959183673,
#  'электросамокат': 0.006751020408163264,
#  'пешеходный': 0.006751020408163264,
#  'завозить': 0.005057142857142856,
#  'парфюмерия': 0.005057142857142856,
#  '«доходы»': 0.006404081632653061,
#  'исчерпывающий': 0.008163265306122448,
#  'рассрочка': 0.03834862017339715,
#  'avaya': 0.00896734693877551,
#  'возобновить': 0.004861224489795918,
#  '(передаточный': 0.006416326530612244,
#  'счет-фактура)': 0.006416326530612244,
#  ...}

# %%
words = [w[0] for w in list(trend_sum.items())]
num = [w[1] for w in list(trend_sum.items())]
df = pd.DataFrame({'word': words, 'num': num})
df.to_csv('trend_sum.csv')

words = [w[0] for w in list(trend_sum_dir.items())]
num = [w[1] for w in list(trend_sum_dir.items())]
df = pd.DataFrame({'word': words, 'num': num})
df.to_csv('trend_sum_dir.csv')

# %%
df
# Out:
#                 word       num
# 0               2023  0.542413
# 1        мобилизация  2.493215
# 2               2022  0.571174
# 3                руб  0.423416
# 4       мобилизовать  0.488980
# ...              ...       ...
# 2599           стол"  0.000898
# 2600     «актуальный  0.000898
# 2601             мса  0.000898
# 2602  существенность  0.000898
# 2603         аудита»  0.000898
#
# [2604 rows x 2 columns]
